# %% [markdown]
# # 1. Defining the problem statement
#    Complete the analysis of what sorts of people were likely to survive.
#    In particular, we ask you to apply the tools of machine learning to predict which passengers survived the Titanic tragedy.

# %%
from IPython.display import Image
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg"/>

# %%
# Imports needed for the script
import numpy as np
import pandas as pd
from sklearn import model_selection as ms
import math

# %% [markdown]
# # Collecting the data

# %% [markdown]
# # Data Dictionary
# Survived: 0 = No, 1 = Yes
#
#     pclass: Ticket class 1 = 1st, 2 = 2nd, 3 = 3rd
#     sibsp: # of siblings / spouses aboard the Titanic
#     parch: # of parents / children aboard the Titanic
#     ticket: Ticket number
#     cabin: Cabin number
#     embarked: Port of Embarkation C = Cherbourg, Q = Queenstown, S = Southampton

# %%
titanic = pd.read_excel("titanic3.xls")
titanic.head(80)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
# 20       1         1                      Beckwith, Mr. Richard Leonard
# 21       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22       1         1                              Behr, Mr. Karl Howell
# 23       1         1                              Bidois, Miss. Rosalie
# 24       1         1                                  Bird, Miss. Ellen
# 25       1         0                                Birnbaum, Mr. Jakob
# 26       1         1                            Bishop, Mr. Dickinson H
# 27       1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28       1         1                             Bissette, Miss. Amelia
# 29       1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ..     ...       ...                                                ...
# 50       1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 51       1         0                           Carlsson, Mr. Frans Olof
# 52       1         0                            Carrau, Mr. Francisco M
# 53       1         0                             Carrau, Mr. Jose Pedro
# 54       1         1                Carter, Master. William Thornton II
# 55       1         1                          Carter, Miss. Lucile Polk
# 56       1         1                         Carter, Mr. William Ernest
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 58       1         0                             Case, Mr. Howard Brown
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 63       1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 64       1         1                      Chambers, Mr. Norman Campbell
# 65       1         1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 66       1         1                        Chaudanson, Miss. Victorine
# 67       1         1                               Cherry, Miss. Gladys
# 68       1         1                           Chevre, Mr. Paul Romaine
# 69       1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70       1         0              Chisholm, Mr. Roderick Robert Crispin
# 71       1         0                           Clark, Mr. Walter Miller
# 72       1         1      Clark, Mrs. Walter Miller (Virginia McDowell)
# 73       1         1                               Cleaver, Miss. Alice
# 74       1         0                        Clifford, Mr. George Quincy
# 75       1         0                         Colley, Mr. Edward Pomeroy
# 76       1         1                        Compton, Miss. Sara Rebecca
# 77       1         0                   Compton, Mr. Alexander Taylor Jr
# 78       1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 79       1         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
#
#        sex      age  sibsp  parch       ticket      fare        cabin  \
# 0   female  29.0000      0      0        24160  211.3375           B5
# 1     male   0.9167      1      2       113781  151.5500      C22 C26
# 2   female   2.0000      1      2       113781  151.5500      C22 C26
# 3     male  30.0000      1      2       113781  151.5500      C22 C26
# 4   female  25.0000      1      2       113781  151.5500      C22 C26
# 5     male  48.0000      0      0        19952   26.5500          E12
# 6   female  63.0000      1      0        13502   77.9583           D7
# 7     male  39.0000      0      0       112050    0.0000          A36
# 8   female  53.0000      2      0        11769   51.4792         C101
# 9     male  71.0000      0      0     PC 17609   49.5042          NaN
# 10    male  47.0000      1      0     PC 17757  227.5250      C62 C64
# 11  female  18.0000      1      0     PC 17757  227.5250      C62 C64
# 12  female  24.0000      0      0     PC 17477   69.3000          B35
# 13  female  26.0000      0      0        19877   78.8500          NaN
# 14    male  80.0000      0      0        27042   30.0000          A23
# 15    male      NaN      0      0     PC 17318   25.9250          NaN
# 16    male  24.0000      0      1     PC 17558  247.5208      B58 B60
# 17  female  50.0000      0      1     PC 17558  247.5208      B58 B60
# 18  female  32.0000      0      0        11813   76.2917          D15
# 19    male  36.0000      0      0        13050   75.2417           C6
# 20    male  37.0000      1      1        11751   52.5542          D35
# 21  female  47.0000      1      1        11751   52.5542          D35
# 22    male  26.0000      0      0       111369   30.0000         C148
# 23  female  42.0000      0      0     PC 17757  227.5250          NaN
# 24  female  29.0000      0      0     PC 17483  221.7792          C97
# 25    male  25.0000      0      0        13905   26.0000          NaN
# 26    male  25.0000      1      0        11967   91.0792          B49
# 27  female  19.0000      1      0        11967   91.0792          B49
# 28  female  35.0000      0      0     PC 17760  135.6333          C99
# 29    male  28.0000      0      0       110564   26.5500          C52
# ..     ...      ...    ...    ...          ...       ...          ...
# 50  female  58.0000      0      1     PC 17755  512.3292  B51 B53 B55
# 51    male  33.0000      0      0          695    5.0000  B51 B53 B55
# 52    male  28.0000      0      0       113059   47.1000          NaN
# 53    male  17.0000      0      0       113059   47.1000          NaN
# 54    male  11.0000      1      2       113760  120.0000      B96 B98
# 55  female  14.0000      1      2       113760  120.0000      B96 B98
# 56    male  36.0000      1      2       113760  120.0000      B96 B98
# 57  female  36.0000      1      2       113760  120.0000      B96 B98
# 58    male  49.0000      0      0        19924   26.0000          NaN
# 59  female      NaN      0      0        17770   27.7208          NaN
# 60    male  36.0000      1      0        19877   78.8500          C46
# 61  female  76.0000      1      0        19877   78.8500          C46
# 62    male  46.0000      1      0  W.E.P. 5734   61.1750          E31
# 63  female  47.0000      1      0  W.E.P. 5734   61.1750          E31
# 64    male  27.0000      1      0       113806   53.1000           E8
# 65  female  33.0000      1      0       113806   53.1000           E8
# 66  female  36.0000      0      0     PC 17608  262.3750          B61
# 67  female  30.0000      0      0       110152   86.5000          B77
# 68    male  45.0000      0      0     PC 17594   29.7000           A9
# 69  female      NaN      0      1       113505   55.0000          E33
# 70    male      NaN      0      0       112051    0.0000          NaN
# 71    male  27.0000      1      0        13508  136.7792          C89
# 72  female  26.0000      1      0        13508  136.7792          C89
# 73  female  22.0000      0      0       113781  151.5500          NaN
# 74    male      NaN      0      0       110465   52.0000          A14
# 75    male  47.0000      0      0         5727   25.5875          E58
# 76  female  39.0000      1      1     PC 17756   83.1583          E49
# 77    male  37.0000      1      1     PC 17756   83.1583          E52
# 78  female  64.0000      0      2     PC 17756   83.1583          E45
# 79  female  55.0000      2      0        11770   25.7000         C101
#
#    embarked boat   body                           home.dest
# 0         S    2    NaN                        St Louis, MO
# 1         S   11    NaN     Montreal, PQ / Chesterville, ON
# 2         S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 3         S  NaN  135.0     Montreal, PQ / Chesterville, ON
# 4         S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 5         S    3    NaN                        New York, NY
# 6         S   10    NaN                          Hudson, NY
# 7         S  NaN    NaN                         Belfast, NI
# 8         S    D    NaN                 Bayside, Queens, NY
# 9         C  NaN   22.0                 Montevideo, Uruguay
# 10        C  NaN  124.0                        New York, NY
# 11        C    4    NaN                        New York, NY
# 12        C    9    NaN                       Paris, France
# 13        S    6    NaN                                 NaN
# 14        S    B    NaN                       Hessle, Yorks
# 15        S  NaN    NaN                        New York, NY
# 16        C  NaN    NaN                        Montreal, PQ
# 17        C    6    NaN                        Montreal, PQ
# 18        C    8    NaN                                 NaN
# 19        C    A    NaN                        Winnipeg, MN
# 20        S    5    NaN                        New York, NY
# 21        S    5    NaN                        New York, NY
# 22        C    5    NaN                        New York, NY
# 23        C    4    NaN                                 NaN
# 24        S    8    NaN                                 NaN
# 25        C  NaN  148.0                   San Francisco, CA
# 26        C    7    NaN                        Dowagiac, MI
# 27        C    7    NaN                        Dowagiac, MI
# 28        S    8    NaN                                 NaN
# 29        S    D    NaN  Stockholm, Sweden / Washington, DC
# ..      ...  ...    ...                                 ...
# 50        C    3    NaN        Germantown, Philadelphia, PA
# 51        S  NaN    NaN                        New York, NY
# 52        S  NaN    NaN                 Montevideo, Uruguay
# 53        S  NaN    NaN                 Montevideo, Uruguay
# 54        S    4    NaN                       Bryn Mawr, PA
# 55        S    4    NaN                       Bryn Mawr, PA
# 56        S    C    NaN                       Bryn Mawr, PA
# 57        S    4    NaN                       Bryn Mawr, PA
# 58        S  NaN    NaN    Ascot, Berkshire / Rochester, NY
# 59        C    5    NaN                        New York, NY
# 60        S  NaN  172.0             Little Onn Hall, Staffs
# 61        S    6    NaN             Little Onn Hall, Staffs
# 62        S  NaN    NaN                          Amenia, ND
# 63        S    4    NaN                          Amenia, ND
# 64        S    5    NaN           New York, NY / Ithaca, NY
# 65        S    5    NaN           New York, NY / Ithaca, NY
# 66        C    4    NaN                                 NaN
# 67        S    8    NaN                     London, England
# 68        C    7    NaN                       Paris, France
# 69        S    6    NaN    St Leonards-on-Sea, England Ohio
# 70        S  NaN    NaN        Liverpool, England / Belfast
# 71        C  NaN    NaN                     Los Angeles, CA
# 72        C    4    NaN                     Los Angeles, CA
# 73        S   11    NaN                                 NaN
# 74        S  NaN    NaN                       Stoughton, MA
# 75        S  NaN    NaN                        Victoria, BC
# 76        C   14    NaN                        Lakewood, NJ
# 77        C  NaN    NaN                        Lakewood, NJ
# 78        C   14    NaN                        Lakewood, NJ
# 79        S    2    NaN                        New York, NY
#
# [80 rows x 14 columns]

# %%
titanic.keys()
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

# %%
def bar_chart(feature):
    survived = titanic[titanic['survived']==1][feature].value_counts()
    dead = titanic[titanic['survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('sex')

# %%
bar_chart('pclass')

# %%
bar_chart('sibsp')

# %%
bar_chart('parch')

# %%
bar_chart('embarked')

# %% [markdown]
# # Cleaning the data

# %%
# Feature that tells whether a passenger had a cabin on the Titanic
titanic['Has_Cabin'] = titanic['cabin'].apply(lambda x: 0 if type(x) == float else 1)
# Create new feature FamilySize as a combination of SibSp and Parch
for dataset in [titanic]:
    dataset['FamilySize'] = dataset['sibsp'] + dataset['parch'] + 1
# Create new feature IsAlone from FamilySize
for dataset in [titanic]:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
# Remove all NULLS in the Embarked column
for dataset in [titanic]:
    dataset['embarked'] = dataset['embarked'].fillna('S')
# Remove all NULLS in the Fare column
for dataset in [titanic]:
    dataset['fare'] = dataset['fare'].fillna(titanic['fare'].mean())
# Remove all NULLS in the Age column
for dataset in [titanic]:
    age_avg = dataset['age'].mean()
    age_std = dataset['age'].std()
    age_null_count = dataset['age'].isnull().sum()
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    dataset.loc[np.isnan(dataset['age']), 'age'] = age_null_random_list
    dataset['age'] = (dataset['age'] + 0.5).astype(int)
for dataset in [titanic]:
    # Mapping Sex
    dataset.loc[ dataset['sex'] == 'male', 'sex'] = 1
    dataset.loc[ dataset['sex'] == 'female', 'sex'] = 1
    # Mapping Embarked
    dataset['embarked'] = dataset['embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
    # Mapping Fare on the basis of fare of persons under 25%, 50%, 75%, 100%
    dataset.loc[ dataset['fare'] <= 7.91, 'fare'] = 0
    dataset.loc[(dataset['fare'] > 7.91) & (dataset['fare'] <= 14.454), 'fare'] = 1
    dataset.loc[(dataset['fare'] > 14.454) & (dataset['fare'] <= 31), 'fare']   = 2
    dataset.loc[ dataset['fare'] > 31, 'fare'] = 3
    dataset['fare'] = dataset['fare'].astype(int)
    
    # Mapping Age
    dataset.loc[ dataset['age'] <= 16, 'age'] = 0
    dataset.loc[(dataset['age'] > 16) & (dataset['age'] <= 32), 'age'] = 1
    dataset.loc[(dataset['age'] > 32) & (dataset['age'] <= 48), 'age'] = 2
    dataset.loc[(dataset['age'] > 48) & (dataset['age'] <= 64), 'age'] = 3
    dataset.loc[ dataset['age'] > 64, 'age'] = 4 ;
# Feature selection: remove variables no longer containing relevant information
drop_elements = ['parch', 'name', 'ticket', 'cabin', 'sibsp','body','boat','home.dest']
titanic = titanic.drop(drop_elements, axis = 1)
#cleaning of data completed

# %%
print(titanic.head())
# Creating header arrays
header = titanic.columns
y_header = [header[1]]
x_header = header.drop('survived')
#save the cleaned titanic file
titanic.to_csv('cleantitanic.csv', encoding = 'utf-8', index = False, header = None)
# Out:
#    pclass  survived  sex  age  fare  embarked  Has_Cabin  FamilySize  IsAlone
# 0       1         1    1    1     3         0          1           1        1
# 1       1         1    1    0     3         0          1           4        0
# 2       1         0    1    0     3         0          1           4        0
# 3       1         0    1    1     3         0          1           4        0
# 4       1         0    1    1     3         0          1           4        0

# %% [markdown]
# # how titanic sank?
# sank from the bow of the ship where third class rooms located
# conclusion, Pclass is key feature for classifier

# %%
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w"/>

# %%
titanic.isnull().sum()
# Out:
# pclass        0
# survived      0
# sex           0
# age           0
# fare          0
# embarked      0
# Has_Cabin     0
# FamilySize    0
# IsAlone       0
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 9 columns):
# pclass        1309 non-null int64
# survived      1309 non-null int64
# sex           1309 non-null int64
# age           1309 non-null int32
# fare          1309 non-null int32
# embarked      1309 non-null int32
# Has_Cabin     1309 non-null int64
# FamilySize    1309 non-null int64
# IsAlone       1309 non-null int64
# dtypes: int32(3), int64(6)
# memory usage: 76.8 KB

# %%
# Splitting x and y data
x_titanic = np.genfromtxt("cleantitanic.csv", delimiter = ",",usecols = (0,2,3,4,5,6,7,8))
y_titanic = np.genfromtxt("cleantitanic.csv", delimiter = ",",usecols = (1))
# Splitting training and testing data
x_train,x_test,y_train,y_test = ms.train_test_split(x_titanic,y_titanic,random_state = 0)
x_train[0]
# Out:
# array([3., 1., 0., 1., 0., 0., 3., 0.])

# %%
def unique_vals(rows, col):
    """Find the unique values for a column in a dataset."""
    return set([int(row[col]) for row in rows])

# %%
# Example
unique_vals(x_train,0)
# Out:
# {1, 2, 3}

# %%
def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {0: 0, 1: 0}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = int(row)
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
# Example
class_counts(y_train)
# Out:
# {0: 601, 1: 380}

# %%
class Question:
    """A Question is used to partition a dataset."""

    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
            condition = "="
            return "Is %s %s %s?" % (x_header[self.column], condition, str(self.value))

# %%
# Example
q =Question(0,1)
q
# Out:
# Is pclass = 1?

# %%
# Example
example = x_train[0]
q.match(example)
# Out:
# False

# %%
def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    t,f = [],[]
    for i in range(len(rows)):
        if question.match(rows[i]):
            t.append(y_train[i])
            true_rows.append(rows[i])
        else:
            f.append(y_train[i])
            false_rows.append(rows[i])
    return class_counts(t), class_counts(f),true_rows,false_rows,t,f

# %%
# Example
t,f,true_rows,false_rows,t_rows,f_rows =partition(x_train,q)
t[0] + t[1]
# Out:
# 247

# %%
def inf_req2(n_values,y_values,t_values): #for actual entropy
    """Getting the entropy for 1 feature on that level using yes values, no values and total values."""
    prob_no = n_values/t_values
    prob_yes = y_values/t_values
    if(n_values!=0 and y_values!=0):
        entropy = -1*(prob_no*math.log(prob_no,10) + prob_yes*math.log(prob_yes,10))
    elif(n_values != 0 and y_values == 0):
        entropy = -1*(prob_no*math.log(prob_no,10))
    elif(n_values == 0 and y_values != 0):
        entropy = -1*(prob_yes*math.log(prob_yes,10))
    else:
        entropy = 0
    if(entropy == -0.0):
        entropy = 0
    return entropy

# %%
def inf_req(n_values,y_values,t_values): # used to find gain as i will get pure node gain will become zero
    """Getting the entropy for 1 feature on that level using yes values, no values and total values."""
    prob_no = n_values/t_values
    prob_yes = y_values/t_values
    if(n_values!=0 and y_values!=0):
        entropy = -1*(prob_no*math.log(prob_no,10) + prob_yes*math.log(prob_yes,10))
    elif(n_values != 0 and y_values == 0):
        t = class_counts(y_train)
        entropy = inf_req(t[0],t[1],t[0]+t[1])
    elif(n_values == 0 and y_values != 0):
        t = class_counts(y_train)
        entropy = inf_req(t[0],t[1],t[0]+t[1])
    else:
        t = class_counts(y_train)
        entropy = inf_req(t[0],t[1],t[0]+t[1])
    return entropy

# %%
# Example
inf_req(t[0],t[1],t[0]+t[1])
# Out:
# 0.28851959636304914

# %%
# information required at level 0
t = class_counts(y_train)
i_req = inf_req(t[0],t[1],t[0]+t[1])
i_req
# Out:
# 0.289914344395204

# %%
def t_inf_req(rows,col,i_req,val):
    """Getting overall entropy on that level."""
    total_value = len(y_train) # total values at level 0
    infreq =0
    q = Question(col,val)
    t,f,true_rows,false_rows,t_rows,f_rows = partition(rows,q)
    infreq = ((t[0]+t[1])/total_value)*inf_req(t[0],t[1],t[0]+t[1]) + ((f[0]+f[1])/total_value)*inf_req(f[0],f[1],f[0]+f[1])
    inf_gain = i_req - infreq
    return inf_gain,infreq

# %%
def split_info(t,f,y_train):
    sinfo = -1*((len(t)/len(y_train))*math.log(len(t)/len(y_train)) + (len(f)/len(y_train))*math.log(len(f)/len(y_train)))
    return sinfo

# %%
split_info(t,f,y_train)
# Out:
# 0.0252616729011434

# %%
def find_best_split(rows,i_req):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None # keep train of the feature / value that produced it
    best_col = 0
    best_val = 0
    n_features = len(rows[0])  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val)

            # try splitting the dataset
            t,f,true_rows, false_rows,t_rows,f_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain , infreq= t_inf_req(rows,col,i_req,val)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question
                best_col, best_val = col, val

    return best_gain, best_question,best_col,best_val

# %%
find_best_split(x_train,i_req)
# Out:
# (0.017920878450286004, Is pclass = 3.0?, 0, 3.0)

# %%
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch,t,f,infreqt,infreqf,gr):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch
        self.t = t
        self.f = f
        self.infreqt = infreqt
        self.infreqf = infreqf
        self.gr = gr

# %% [markdown]
# # Build tree

# %%
def build_tree(rows,y_train,i_req):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # Try partitioing the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.
    gain, question,col,val = find_best_split(rows,i_req)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(y_train)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    t,f,true_rows, false_rows,t_rows,f_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows,t_rows,i_req)
    infreqt = inf_req2(t[0],t[1],t[0]+t[1])

    # Recursively build the false branch.
    false_branch = build_tree(false_rows,f_rows,i_req)
    infreqf = inf_req2(f[0],f[1],f[0]+f[1])
    
    # To find gain ratio
    sinfo = split_info(t,f,y_train)
    if(sinfo !=0):
        gr = gain/sinfo
    else:
        gr = 'infinite'

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # depending on the answer.
    return Decision_Node(question, true_branch, false_branch,t,f,infreqt,infreqf,gr)

# %%
def made(node, spacing="",level = 1, ans = [[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]]):
    """World's most elegant tree printing function."""
    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        level -= 1;
        ans[level] += ["Reached leaf node"]
        return
    
    # Print the question at this node
    ans[level] += [level]
    ans[level] += [str(node.question)]
    a = level + 1

    # Call this function recursively on the true branch
    ans[level] += ['--> True:']
    ans[level] += ["count of 0 =" + str(node.t[0])]
    ans[level] += ["count of 1 =" + str(node.t[1])]
    ans[level] += ["entropy =" + str(node.infreqt)]
    ans[level] += ["gain ratio =" + str(node.gr)]
    made(node.true_branch, spacing + "  ",a, ans)

    # Call this function recursively on the false branch
    ans[level] += [level]
    ans[level] += [str(node.question)]
    ans[level] += ['--> False:']
    ans[level] += ["count of 0 =" + str(node.f[0])]
    ans[level] += ["count of 1 =" + str(node.f[1])]
    ans[level] += ["entropy =" + str(node.infreqf)]
    ans[level] += ["gain ratio =" + str(node.gr)]
    made(node.false_branch, spacing + "  ",a, ans)
    return ans

# %%
def print_tree(node, spacing="",level = 1):
    """World's most elegant tree printing function."""
    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        level -= 1;
        print(spacing + "reached node leaf")
        return
    
    # Print the question at this node
    print(spacing + str(level))
    print (spacing + str(node.question))
    a = level + 1

    # Call this function recursively on the true branch
    print (spacing + '--> True:')
    print(spacing +"count of 0 =", node.t[0])
    print(spacing +"count of 1 =", node.t[1])
    print(spacing +"entropy =",node.infreqt)
    print(spacing +"gain ratio =",node.gr)
    print_tree(node.true_branch, spacing + "      ",a)

    # Call this function recursively on the false branch
    print(spacing + str(level))
    print (spacing + str(node.question))
    print (spacing + '--> False:')
    print(spacing +"count of 0 =", node.f[0])
    print(spacing +"count of 1 =", node.f[1])
    print(spacing +"entropy =",node.infreqf)
    print(spacing +"gain ratio =",node.gr)
    print_tree(node.false_branch, spacing + "      ",a)

# %%
# Building the tree
my_tree = build_tree(x_train,y_train,i_req)
ans =made(my_tree)
ans[0] += [0]
ans[0] += ["count of 0 =" + str(class_counts(y_train)[0])]
ans[0] += ["count of 1 =" + str(class_counts(y_train)[1])]
ans[0] += ["entropy =" + str(inf_req(class_counts(y_train)[0],class_counts(y_train)[1],len(y_train)))]
ans
# Out:
# [[0, 'count of 0 =601', 'count of 1 =380', 'entropy =0.289914344395204'],
#  [1,
#   'Is pclass = 3.0?',
#   '--> True:',
#   'count of 0 =394',
#   'count of 1 =138',
#   'entropy =0.24860181025999772',
#   'gain ratio =0.7094098051390281',
#   1,
#   'Is pclass = 3.0?',
#   '--> False:',
#   'count of 0 =207',
#   'count of 1 =242',
#   'entropy =0.2997091916116832',
#   'gain ratio =0.7094098051390281'],
#  [2,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =83',
#   'count of 1 =30',
#   'entropy =0.25133402482143735',
#   'gain ratio =3.2325421359614257',
#   2,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =249',
#   'count of 1 =170',
#   'entropy =0.29326425193730976',
#   'gain ratio =3.2325421359614257',
#   2,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =102',
#   'count of 1 =90',
#   'entropy =0.30018121115534735',
#   'gain ratio =3.295629434700096',
#   2,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =172',
#   'count of 1 =85',
#   'entropy =0.2756471250674296',
#   'gain ratio =3.295629434700096'],
#  [3,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =12',
#   'count of 1 =16',
#   'entropy =0.296583221518423',
#   'gain ratio =1.7979833046088225',
#   3,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =54',
#   'count of 1 =31',
#   'entropy =0.28493097819308383',
#   'gain ratio =1.7979833046088225',
#   3,
#   'Is FamilySize = 6.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =3',
#   'entropy =0.24421905028821553',
#   'gain ratio =3.253876143453362',
#   3,
#   'Is FamilySize = 6.0?',
#   '--> False:',
#   'count of 0 =253',
#   'count of 1 =162',
#   'entropy =0.2905037010171815',
#   'gain ratio =3.253876143453362',
#   3,
#   'Is fare = 0.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =3',
#   'entropy =0.24421905028821553',
#   'gain ratio =2.451632095752773',
#   'Reached leaf node',
#   3,
#   'Is fare = 0.0?',
#   '--> False:',
#   'count of 0 =114',
#   'count of 1 =74',
#   'entropy =0.2911243369634132',
#   'gain ratio =2.451632095752773',
#   3,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =34',
#   'count of 1 =12',
#   'entropy =0.24926961142052684',
#   'gain ratio =2.837972253084021',
#   3,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =121',
#   'count of 1 =90',
#   'entropy =0.2963257934122438',
#   'gain ratio =2.837972253084021'],
#  [4,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =4',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.7479716393866527',
#   4,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =14',
#   'count of 1 =9',
#   'entropy =0.2906854410415382',
#   'gain ratio =0.7479716393866527',
#   4,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =11',
#   'count of 1 =14',
#   'entropy =0.29789552722260526',
#   'gain ratio =1.4987252020957151',
#   4,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =36',
#   'count of 1 =24',
#   'entropy =0.29228525323862886',
#   'gain ratio =1.4987252020957151',
#   4,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   4,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   4,
#   'Is embarked = 0.0?',
#   '--> True:',
#   'count of 0 =177',
#   'count of 1 =129',
#   'entropy =0.2956647572834006',
#   'gain ratio =3.25533973457356',
#   4,
#   'Is embarked = 0.0?',
#   '--> False:',
#   'count of 0 =74',
#   'count of 1 =35',
#   'entropy =0.2726051326896889',
#   'gain ratio =3.25533973457356',
#   4,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =34',
#   'count of 1 =16',
#   'entropy =0.27224594629738935',
#   'gain ratio =2.421778077331488',
#   4,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =77',
#   'count of 1 =61',
#   'entropy =0.29810440687994744',
#   'gain ratio =2.421778077331488',
#   4,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =12',
#   'count of 1 =6',
#   'entropy =0.27643459094367495',
#   'gain ratio =1.0133138312200436',
#   4,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =13',
#   'count of 1 =15',
#   'entropy =0.2999211575627872',
#   'gain ratio =1.0133138312200436',
#   4,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =65',
#   'count of 1 =34',
#   'entropy =0.27937608993873897',
#   'gain ratio =2.576519765206665',
#   4,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =61',
#   'count of 1 =51',
#   'entropy =0.29929660377150713',
#   'gain ratio =2.576519765206665'],
#  [5,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   5,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   5,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =5',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.6671460576544932',
#   5,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =10',
#   'count of 1 =6',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.6671460576544932',
#   5,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =4',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.6999162521098828',
#   5,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =12',
#   'count of 1 =8',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.6999162521098828',
#   5,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =12',
#   'count of 1 =15',
#   'entropy =0.2983436219957756',
#   'gain ratio =1.2046170820158963',
#   5,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =24',
#   'count of 1 =9',
#   'entropy =0.2544759887859944',
#   'gain ratio =1.2046170820158963',
#   5,
#   'Is fare = 1.0?',
#   '--> True:',
#   'count of 0 =85',
#   'count of 1 =40',
#   'entropy =0.27224594629738935',
#   'gain ratio =3.0420431896080977',
#   5,
#   'Is fare = 1.0?',
#   '--> False:',
#   'count of 0 =99',
#   'count of 1 =82',
#   'entropy =0.2991116126558021',
#   'gain ratio =3.0420431896080977',
#   5,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =36',
#   'count of 1 =31',
#   'entropy =0.2998195409622474',
#   'gain ratio =1.7521549622375538',
#   5,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =26',
#   'count of 1 =16',
#   'entropy =0.2886010339756132',
#   'gain ratio =1.7521549622375538',
#   5,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =3',
#   'entropy =0.27643459094367495',
#   'gain ratio =1.0673198551209093',
#   5,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =22',
#   'count of 1 =19',
#   'entropy =0.2998663592516309',
#   'gain ratio =1.0673198551209093',
#   5,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =18',
#   'count of 1 =21',
#   'entropy =0.2997438305836322',
#   'gain ratio =2.033175400049098',
#   5,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =64',
#   'count of 1 =35',
#   'entropy =0.2821210543225153',
#   'gain ratio =2.033175400049098',
#   5,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =4',
#   'entropy =0.2846721173935298',
#   'gain ratio =0.5834211774215886',
#   5,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =5',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.5834211774215886',
#   5,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =9',
#   'count of 1 =3',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.7486333607941373',
#   5,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =10',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.7486333607941373',
#   5,
#   'Is embarked = 0.0?',
#   '--> True:',
#   'count of 0 =24',
#   'count of 1 =32',
#   'entropy =0.296583221518423',
#   'gain ratio =1.6575265513429946',
#   5,
#   'Is embarked = 0.0?',
#   '--> False:',
#   'count of 0 =30',
#   'count of 1 =13',
#   'entropy =0.2661451713568248',
#   'gain ratio =1.6575265513429946',
#   5,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =14',
#   'count of 1 =4',
#   'entropy =0.23004847928068484',
#   'gain ratio =1.7876649482528826',
#   5,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =51',
#   'count of 1 =43',
#   'entropy =0.29945527305802866',
#   'gain ratio =1.7876649482528826'],
#  [6,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   6,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   6,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =6',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.5492325495987298',
#   6,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.5492325495987298',
#   6,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   6,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   6,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.6171884653350107',
#   'Reached leaf node',
#   6,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =8',
#   'entropy =0.2893610509517873',
#   'gain ratio =0.6171884653350107',
#   6,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =8',
#   'count of 1 =2',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.7334667455875343',
#   6,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =11',
#   'entropy =0.28196497790519526',
#   'gain ratio =0.7334667455875343',
#   6,
#   'Is FamilySize = 6.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =1',
#   'entropy =0.16362920197946884',
#   'gain ratio =0.8269196226802819',
#   6,
#   'Is FamilySize = 6.0?',
#   '--> False:',
#   'count of 0 =11',
#   'count of 1 =14',
#   'entropy =0.29789552722260526',
#   'gain ratio =0.8269196226802819',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =51',
#   'count of 1 =43',
#   'entropy =0.29945527305802866',
#   'gain ratio =1.9148542061115812',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =23',
#   'count of 1 =8',
#   'entropy =0.24799201240394408',
#   'gain ratio =1.9148542061115812',
#   6,
#   'Is FamilySize = 7.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =8',
#   'entropy =0.2544759887859944',
#   'gain ratio =2.3782357838800934',
#   6,
#   'Is FamilySize = 7.0?',
#   '--> False:',
#   'count of 0 =104',
#   'count of 1 =66',
#   'entropy =0.2900879388321769',
#   'gain ratio =2.3782357838800934',
#   6,
#   'Is age = 0.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =3',
#   'entropy =0.29228525323862886',
#   'gain ratio =1.2867394675020063',
#   6,
#   'Is age = 0.0?',
#   '--> False:',
#   'count of 0 =36',
#   'count of 1 =26',
#   'entropy =0.29535625280690536',
#   'gain ratio =1.2867394675020063',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =23',
#   'count of 1 =15',
#   'entropy =0.2913333567683929',
#   'gain ratio =0.9568643546473707',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =4',
#   'entropy =0',
#   'gain ratio =0.9568643546473707',
#   6,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.4299744410916737',
#   'Reached leaf node',
#   6,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4299744410916737',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =10',
#   'count of 1 =3',
#   'entropy =0.23460767814076078',
#   'gain ratio =0.9445648266069196',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =12',
#   'count of 1 =16',
#   'entropy =0.296583221518423',
#   'gain ratio =0.9445648266069196',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =8',
#   'entropy =0.296583221518423',
#   'gain ratio =0.9132640577180328',
#   6,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =15',
#   'count of 1 =10',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.9132640577180328',
#   6,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =10',
#   'count of 1 =3',
#   'entropy =0.23460767814076078',
#   'gain ratio =1.651865903185071',
#   6,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =44',
#   'count of 1 =42',
#   'entropy =0.30091254470747386',
#   'gain ratio =1.651865903185071',
#   6,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4623898530505439',
#   'Reached leaf node',
#   6,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4623898530505439',
#   6,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.402210281499661',
#   6,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.402210281499661',
#   'Reached leaf node',
#   6,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4795734770546406',
#   'Reached leaf node',
#   6,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =7',
#   'count of 1 =4',
#   'entropy =0.2846721173935298',
#   'gain ratio =0.4795734770546406',
#   6,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =6',
#   'entropy =0.2997438305836322',
#   'gain ratio =0.5484103928728944',
#   6,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.5484103928728944',
#   6,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =31',
#   'count of 1 =18',
#   'entropy =0.28556102695255525',
#   'gain ratio =1.149234317943044',
#   6,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =4',
#   'entropy =0.296583221518423',
#   'gain ratio =1.149234317943044',
#   6,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =11',
#   'count of 1 =13',
#   'entropy =0.2995202785145496',
#   'gain ratio =0.9707453814832824',
#   6,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =12',
#   'count of 1 =7',
#   'entropy =0.28581353607539234',
#   'gain ratio =0.9707453814832824',
#   6,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =7',
#   'entropy =0.2949698875659671',
#   'gain ratio =0.5829032666712504',
#   6,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.5829032666712504',
#   6,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =20',
#   'entropy =0.2485383495893791',
#   'gain ratio =1.6113424212521876',
#   6,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =44',
#   'count of 1 =23',
#   'entropy =0.27933363861430577',
#   'gain ratio =1.6113424212521876'],
#  [7,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =1',
#   'entropy =0.1956762467702946',
#   'gain ratio =0.43063768594438967',
#   'Reached leaf node',
#   7,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.43063768594438967',
#   'Reached leaf node',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.40241297178855523',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.40241297178855523',
#   7,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4964699832320515',
#   'Reached leaf node',
#   7,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =6',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4964699832320515',
#   'Reached leaf node',
#   7,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4459363042364095',
#   'Reached leaf node',
#   7,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =3',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4459363042364095',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.5661477947176021',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =5',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.5661477947176021',
#   7,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.4150505329368685',
#   'Reached leaf node',
#   7,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =2',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4150505329368685',
#   7,
#   'Is FamilySize = 4.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.6995848191876056',
#   7,
#   'Is FamilySize = 4.0?',
#   '--> False:',
#   'count of 0 =9',
#   'count of 1 =11',
#   'entropy =0.2988548895792612',
#   'gain ratio =0.6995848191876056',
#   7,
#   'Is age = 0.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =1.5951434955011339',
#   'Reached leaf node',
#   7,
#   'Is age = 0.0?',
#   '--> False:',
#   'count of 0 =50',
#   'count of 1 =41',
#   'entropy =0.29890250943856506',
#   'gain ratio =1.5951434955011339',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =3',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.7937279129037291',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =15',
#   'count of 1 =12',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.7937279129037291',
#   7,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4623898530505439',
#   7,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4623898530505439',
#   'Reached leaf node',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =3',
#   'entropy =0',
#   'gain ratio =2.288608601532368',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =100',
#   'count of 1 =67',
#   'entropy =0.29249484371671275',
#   'gain ratio =2.288608601532368',
#   7,
#   'Is fare = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   7,
#   'Is fare = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   7,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =9',
#   'count of 1 =10',
#   'entropy =0.30042820174472773',
#   'gain ratio =1.2267541455046733',
#   7,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =28',
#   'count of 1 =15',
#   'entropy =0.28086860061639213',
#   'gain ratio =1.2267541455046733',
#   7,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =11',
#   'count of 1 =13',
#   'entropy =0.2995202785145496',
#   'gain ratio =0.8997798802592469',
#   7,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =10',
#   'count of 1 =4',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.8997798802592469',
#   7,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   7,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   7,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.49738531336255254',
#   7,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =5',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.49738531336255254',
#   7,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =4',
#   'entropy =0.296583221518423',
#   'gain ratio =0.7465333207591033',
#   'Reached leaf node',
#   7,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =12',
#   'count of 1 =9',
#   'entropy =0.296583221518423',
#   'gain ratio =0.7465333207591033',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =4',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5139962686547342',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.5139962686547342',
#   7,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =11',
#   'count of 1 =7',
#   'entropy =0.2902166263899575',
#   'gain ratio =0.699637872341739',
#   7,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =5',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.699637872341739',
#   7,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.496580905311079',
#   7,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =5',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.496580905311079',
#   7,
#   'Is FamilySize = 6.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =1.5082540279416548',
#   'Reached leaf node',
#   7,
#   'Is FamilySize = 6.0?',
#   '--> False:',
#   'count of 0 =44',
#   'count of 1 =38',
#   'entropy =0.2998663592516309',
#   'gain ratio =1.5082540279416548',
#   7,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.446300157816263',
#   'Reached leaf node',
#   7,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =3',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.446300157816263',
#   7,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.3936395446599453',
#   'Reached leaf node',
#   7,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.3936395446599453',
#   'Reached leaf node',
#   7,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =2',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4622789628769931',
#   7,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =3',
#   'entropy =0.296583221518423',
#   'gain ratio =0.4622789628769931',
#   7,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.4968953054835638',
#   'Reached leaf node',
#   7,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =5',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.4968953054835638',
#   7,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   7,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   7,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =18',
#   'count of 1 =11',
#   'entropy =0.2882523210506807',
#   'gain ratio =1.0543209894111785',
#   7,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =9',
#   'count of 1 =11',
#   'entropy =0.2988548895792612',
#   'gain ratio =1.0543209894111785',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.40241297178855523',
#   'Reached leaf node',
#   7,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.40241297178855523',
#   7,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =5',
#   'entropy =0.2949698875659671',
#   'gain ratio =0.6825961588521482',
#   7,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =7',
#   'entropy =0.2949698875659671',
#   'gain ratio =0.6825961588521482',
#   7,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =8',
#   'entropy =0.296583221518423',
#   'gain ratio =0.6004228319408282',
#   7,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.6004228319408282',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4793966483422553',
#   'Reached leaf node',
#   7,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4793966483422553',
#   'Reached leaf node',
#   7,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.3933995916565733',
#   'Reached leaf node',
#   7,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.3933995916565733',
#   'Reached leaf node',
#   7,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =8',
#   'count of 1 =3',
#   'entropy =0.2544759887859944',
#   'gain ratio =0.732330949779351',
#   7,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =10',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.732330949779351',
#   7,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =25',
#   'count of 1 =15',
#   'entropy =0.28731326376205835',
#   'gain ratio =1.2875233673882147',
#   7,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =13',
#   'count of 1 =14',
#   'entropy =0.30073205751142396',
#   'gain ratio =1.2875233673882147'],
#  [8,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   8,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   8,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   8,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.42974552513914027',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =3',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.42974552513914027',
#   'Reached leaf node',
#   8,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4457419542814002',
#   'Reached leaf node',
#   8,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =3',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.4457419542814002',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 5.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =2',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.40203179978677983',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 5.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.40203179978677983',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4165198575453182',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4165198575453182',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =7',
#   'entropy =0.2652949955741215',
#   'gain ratio =0.6177962341612385',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =7',
#   'count of 1 =3',
#   'entropy =0.2652949955741215',
#   'gain ratio =0.6177962341612385',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =1.5627522091555708',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =50',
#   'count of 1 =40',
#   'entropy =0.2983436219957756',
#   'gain ratio =1.5627522091555708',
#   8,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   8,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =8',
#   'count of 1 =10',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.7311099605457801',
#   8,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =3',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.7311099605457801',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4456034007828225',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =4',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4456034007828225',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =22',
#   'count of 1 =9',
#   'entropy =0.2616364821232255',
#   'gain ratio =2.2676097762366583',
#   8,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =76',
#   'count of 1 =60',
#   'entropy =0.2980175257499325',
#   'gain ratio =2.2676097762366583',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5995166625125501',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =10',
#   'count of 1 =8',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.5995166625125501',
#   8,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =2',
#   'entropy =0',
#   'gain ratio =0.9701368414323442',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =23',
#   'count of 1 =18',
#   'entropy =0.2977925074450002',
#   'gain ratio =0.9701368414323442',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.6823902049485451',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =10',
#   'count of 1 =12',
#   'entropy =0.2992329102507745',
#   'gain ratio =0.6823902049485451',
#   8,
#   'Is fare = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5140242099858494',
#   'Reached leaf node',
#   8,
#   'Is fare = 1.0?',
#   '--> False:',
#   'count of 0 =8',
#   'count of 1 =5',
#   'entropy =0.2893610509517873',
#   'gain ratio =0.5140242099858494',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   8,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   8,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   8,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =1',
#   'entropy =0.1956762467702946',
#   'gain ratio =0.4156786567897574',
#   'Reached leaf node',
#   8,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =2',
#   'entropy =0',
#   'gain ratio =0.4156786567897574',
#   'Reached leaf node',
#   8,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.6334605613180613',
#   'Reached leaf node',
#   8,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =8',
#   'count of 1 =9',
#   'entropy =0.3002781872083049',
#   'gain ratio =0.6334605613180613',
#   8,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =3',
#   'entropy =0.296583221518423',
#   'gain ratio =0.41477846401879376',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.41477846401879376',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =2',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.39335420765642476',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39335420765642476',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =9',
#   'entropy =0.2976281785900671',
#   'gain ratio =0.5826034026592789',
#   8,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5826034026592789',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 5.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4029002651346722',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 5.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =1',
#   'entropy =0.1956762467702946',
#   'gain ratio =0.4029002651346722',
#   8,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =3',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4459363042364095',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4459363042364095',
#   'Reached leaf node',
#   8,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =32',
#   'count of 1 =28',
#   'entropy =0.30006418065332474',
#   'gain ratio =1.4638582412233407',
#   8,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =14',
#   'count of 1 =8',
#   'entropy =0.2846721173935298',
#   'gain ratio =1.4638582412233407',
#   8,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   8,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   8,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   8,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4025803021264083',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.4025803021264083',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =2',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.4302712424426356',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4302712424426356',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =8',
#   'count of 1 =10',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.7625039016153942',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =7',
#   'count of 1 =4',
#   'entropy =0.2846721173935298',
#   'gain ratio =0.7625039016153942',
#   8,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =8',
#   'entropy =0.2893610509517873',
#   'gain ratio =0.6171884653350107',
#   8,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.6171884653350107',
#   8,
#   'Is FamilySize = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   8,
#   'Is FamilySize = 4.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4793966483422553',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4793966483422553',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4795734770546406',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =7',
#   'count of 1 =4',
#   'entropy =0.2846721173935298',
#   'gain ratio =0.4795734770546406',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =3',
#   'entropy =0.2652949955741215',
#   'gain ratio =0.514797538708808',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =3',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.514797538708808',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   8,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.39373831991943087',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4623898530505439',
#   'Reached leaf node',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4623898530505439',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =5',
#   'entropy =0.2992329102507745',
#   'gain ratio =0.5483574210943932',
#   8,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =3',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.5483574210943932',
#   8,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =16',
#   'count of 1 =18',
#   'entropy =0.3002781872083049',
#   'gain ratio =0.9290227807215173',
#   8,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =1',
#   'entropy =0.1956762467702946',
#   'gain ratio =0.9290227807215173',
#   8,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =10',
#   'count of 1 =11',
#   'entropy =0.3005374120319918',
#   'gain ratio =0.7308144035140441',
#   8,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.7308144035140441'],
#  [9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4459363042364095',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =3',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4459363042364095',
#   9,
#   'Is FamilySize = 5.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.44573432183404277',
#   'Reached leaf node',
#   9,
#   'Is FamilySize = 5.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =3',
#   'entropy =0.296583221518423',
#   'gain ratio =0.44573432183404277',
#   9,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =34',
#   'count of 1 =29',
#   'entropy =0.2996607856677658',
#   'gain ratio =1.552093799532032',
#   'Reached leaf node',
#   9,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =16',
#   'count of 1 =11',
#   'entropy =0.29354008789101427',
#   'gain ratio =1.552093799532032',
#   9,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   9,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5830615750725547',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =9',
#   'entropy =0.2830542780615224',
#   'gain ratio =0.5830615750725547',
#   9,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.43000107543396365',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.43000107543396365',
#   9,
#   'Is age = 0.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =3',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.7932073639315526',
#   9,
#   'Is age = 0.0?',
#   '--> False:',
#   'count of 0 =11',
#   'count of 1 =12',
#   'entropy =0.30061937996055055',
#   'gain ratio =0.7932073639315526',
#   9,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =60',
#   'count of 1 =36',
#   'entropy =0.28731326376205835',
#   'gain ratio =2.010793092299051',
#   9,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =21',
#   'count of 1 =19',
#   'entropy =0.30048690114006105',
#   'gain ratio =2.010793092299051',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =8',
#   'count of 1 =9',
#   'entropy =0.3002781872083049',
#   'gain ratio =0.5824932470515023',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5824932470515023',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =22',
#   'count of 1 =18',
#   'entropy =0.2988548895792612',
#   'gain ratio =0.9414864750223093',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.9414864750223093',
#   'Reached leaf node',
#   9,
#   'Is fare = 1.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.6497300697289198',
#   'Reached leaf node',
#   9,
#   'Is fare = 1.0?',
#   '--> False:',
#   'count of 0 =12',
#   'count of 1 =9',
#   'entropy =0.296583221518423',
#   'gain ratio =0.6497300697289198',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =5',
#   'entropy =0.2949698875659671',
#   'gain ratio =0.4965986943381931',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4965986943381931',
#   'Reached leaf node',
#   9,
#   'Is FamilySize = 2.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =9',
#   'entropy =0.2830542780615224',
#   'gain ratio =0.565963830663435',
#   'Reached leaf node',
#   9,
#   'Is FamilySize = 2.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.565963830663435',
#   9,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =7',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.548232923519123',
#   'Reached leaf node',
#   9,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.548232923519123',
#   'Reached leaf node',
#   9,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39347237433582527',
#   'Reached leaf node',
#   9,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39347237433582527',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =34',
#   'count of 1 =19',
#   'entropy =0.283396594175498',
#   'gain ratio =1.2028826220808297',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =5',
#   'entropy =0.25982518101310587',
#   'gain ratio =1.2028826220808297',
#   9,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =11',
#   'count of 1 =6',
#   'entropy =0.28196497790519526',
#   'gain ratio =0.6512221233027323',
#   9,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =4',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.6512221233027323',
#   'Reached leaf node',
#   9,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =3',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.41474903396976975',
#   'Reached leaf node',
#   9,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.41474903396976975',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =4',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.46226753431002204',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.46226753431002204',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.49738531336255254',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =5',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.49738531336255254',
#   9,
#   'Is FamilySize = 4.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.4025803021264083',
#   9,
#   'Is FamilySize = 4.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4025803021264083',
#   9,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   9,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =4',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.4623898530505439',
#   9,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4623898530505439',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =4',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.445624082989276',
#   'Reached leaf node',
#   9,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.445624082989276',
#   'Reached leaf node',
#   9,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   9,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
# ...
#   'count of 0 =12',
#   'count of 1 =13',
#   'entropy =0.30068246736962256',
#   'gain ratio =0.7304786609260059',
#   'Reached leaf node',
#   10,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =3',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.513926892375438',
#   'Reached leaf node',
#   10,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =3',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.513926892375438',
#   'Reached leaf node',
#   10,
#   'Is age = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   10,
#   'Is age = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 11.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4151568681974367',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 11.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.4151568681974367',
#   10,
#   'Is FamilySize = 11.0?',
#   '--> True:',
#   'count of 0 =6',
#   'count of 1 =3',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.6666077911297065',
#   10,
#   'Is FamilySize = 11.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =8',
#   'entropy =0.296583221518423',
#   'gain ratio =0.6666077911297065',
#   10,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =46',
#   'count of 1 =42',
#   'entropy =0.3005811897176206',
#   'gain ratio =1.6178501756768442',
#   'Reached leaf node',
#   10,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =2',
#   'entropy =0.24421905028821553',
#   'gain ratio =1.6178501756768442',
#   'Reached leaf node',
#   10,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =17',
#   'count of 1 =10',
#   'entropy =0.28626629514303703',
#   'gain ratio =0.9295994925651659',
#   10,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =9',
#   'entropy =0.268064694594085',
#   'gain ratio =0.9295994925651659',
#   10,
#   'Is FamilySize = 6.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 6.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 4.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   10,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =5',
#   'entropy =0.1956762467702946',
#   'gain ratio =1.112277712944978',
#   10,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =30',
#   'count of 1 =17',
#   'entropy =0.284198511020387',
#   'gain ratio =1.112277712944978',
#   10,
#   'Is FamilySize = 4.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.40207823261175457',
#   10,
#   'Is FamilySize = 4.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.40207823261175457',
#   10,
#   'Is FamilySize = 3.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5656974126018595',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 3.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =9',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.5656974126018595',
#   10,
#   'Is FamilySize = 6.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4149333652853543',
#   'Reached leaf node',
#   10,
#   'Is FamilySize = 6.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4149333652853543',
#   'Reached leaf node',
#   10,
#   'Is pclass = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   10,
#   'Is pclass = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   10,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   10,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   10,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4457419542814002',
#   'Reached leaf node',
#   10,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =3',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.4457419542814002',
#   'Reached leaf node',
#   10,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   10,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   10,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.42974552513914027',
#   'Reached leaf node',
#   10,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =3',
#   'entropy =0.28731326376205835',
#   'gain ratio =0.42974552513914027',
#   10,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =2',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.4458018687241752',
#   'Reached leaf node',
#   10,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4458018687241752',
#   'Reached leaf node',
#   10,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   10,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   10,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.7937996579818876',
#   10,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =11',
#   'count of 1 =13',
#   'entropy =0.2995202785145496',
#   'gain ratio =0.7937996579818876',
#   10,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   10,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.39373831991943087',
#   10,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =3',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.46254234189986737',
#   'Reached leaf node',
#   10,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.46254234189986737',
#   10,
#   'Is embarked = 1.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.44573432183404277',
#   10,
#   'Is embarked = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =3',
#   'entropy =0.296583221518423',
#   'gain ratio =0.44573432183404277',
#   'Reached leaf node'],
#  [11,
#   'Is FamilySize = 5.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   11,
#   'Is FamilySize = 5.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   11,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.43019947530402425',
#   'Reached leaf node',
#   11,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =2',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.43019947530402425',
#   'Reached leaf node',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =5',
#   'entropy =0.2983436219957756',
#   'gain ratio =0.5145374109422556',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.5145374109422556',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =13',
#   'count of 1 =13',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.7304263054404239',
#   'Reached leaf node',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.7304263054404239',
#   'Reached leaf node',
#   11,
#   'Is age = 0.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =4',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.49652769699328975',
#   11,
#   'Is age = 0.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.49652769699328975',
#   11,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.3939212620188948',
#   'Reached leaf node',
#   11,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.3939212620188948',
#   'Reached leaf node',
#   11,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =1.0258084958584508',
#   'Reached leaf node',
#   11,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =25',
#   'count of 1 =20',
#   'entropy =0.2983436219957756',
#   'gain ratio =1.0258084958584508',
#   11,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   11,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   11,
#   'Is fare = 3.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39348414120425745',
#   'Reached leaf node',
#   11,
#   'Is fare = 3.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.39348414120425745',
#   'Reached leaf node',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =7',
#   'count of 1 =5',
#   'entropy =0.2949698875659671',
#   'gain ratio =0.5312801312644392',
#   'Reached leaf node',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.5312801312644392',
#   'Reached leaf node',
#   11,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4151568681974367',
#   'Reached leaf node',
#   11,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =5',
#   'count of 1 =2',
#   'entropy =0.25982518101310587',
#   'gain ratio =0.4151568681974367',
#   'Reached leaf node',
#   11,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   11,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =infinite',
#   'Reached leaf node',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =3',
#   'count of 1 =2',
#   'entropy =0.29228525323862886',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   11,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.40207823261175457',
#   'Reached leaf node',
#   11,
#   'Is Has_Cabin = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =2',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.6824452486761677',
#   'Reached leaf node',
#   11,
#   'Is Has_Cabin = 1.0?',
#   '--> False:',
#   'count of 0 =11',
#   'count of 1 =10',
#   'entropy =0.3005374120319918',
#   'gain ratio =0.6824452486761677',
#   11,
#   'Is fare = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.4166120232031104',
#   11,
#   'Is fare = 2.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.4166120232031104',
#   'Reached leaf node',
#   11,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.3939212620188948',
#   'Reached leaf node',
#   11,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =1',
#   'entropy =0.21732201127364886',
#   'gain ratio =0.3939212620188948',
#   'Reached leaf node',
#   11,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node',
#   11,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.5346226168533992',
#   'Reached leaf node'],
#  [12,
#   'Is age = 3.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.4302712424426356',
#   'Reached leaf node',
#   12,
#   'Is age = 3.0?',
#   '--> False:',
#   'count of 0 =6',
#   'count of 1 =2',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.4302712424426356',
#   12,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =2',
#   'count of 1 =1',
#   'entropy =0.27643459094367495',
#   'gain ratio =0.39354037675017295',
#   12,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =2',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39354037675017295',
#   'Reached leaf node',
#   12,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =4',
#   'count of 1 =3',
#   'entropy =0.296583221518423',
#   'gain ratio =0.41477846401879376',
#   'Reached leaf node',
#   12,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.41477846401879376',
#   'Reached leaf node',
#   12,
#   'Is age = 4.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   12,
#   'Is age = 4.0?',
#   '--> False:',
#   'count of 0 =3',
#   'count of 1 =1',
#   'entropy =0.24421905028821553',
#   'gain ratio =0.39373831991943087',
#   'Reached leaf node',
#   12,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.9979789006708518',
#   'Reached leaf node',
#   12,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =24',
#   'count of 1 =20',
#   'entropy =0.2992329102507745',
#   'gain ratio =0.9979789006708518',
#   'Reached leaf node',
#   12,
#   'Is embarked = 2.0?',
#   '--> True:',
#   'count of 0 =0',
#   'count of 1 =1',
#   'entropy =0',
#   'gain ratio =0.6330385793447761',
#   'Reached leaf node',
#   12,
#   'Is embarked = 2.0?',
#   '--> False:',
#   'count of 0 =11',
#   'count of 1 =9',
#   'entropy =0.2988548895792612',
#   'gain ratio =0.6330385793447761',
#   'Reached leaf node',
#   12,
#   'Is IsAlone = 1.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   12,
#   'Is IsAlone = 1.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node'],
#  [13,
#   'Is age = 2.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.41477846401879376',
#   'Reached leaf node',
#   13,
#   'Is age = 2.0?',
#   '--> False:',
#   'count of 0 =4',
#   'count of 1 =3',
#   'entropy =0.296583221518423',
#   'gain ratio =0.41477846401879376',
#   'Reached leaf node',
#   13,
#   'Is FamilySize = 5.0?',
#   '--> True:',
#   'count of 0 =1',
#   'count of 1 =0',
#   'entropy =0',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node',
#   13,
#   'Is FamilySize = 5.0?',
#   '--> False:',
#   'count of 0 =1',
#   'count of 1 =1',
#   'entropy =0.30102999566398114',
#   'gain ratio =0.5345806985518538',
#   'Reached leaf node'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
# To remove the left [] and putting ans in list levelwise
li = []
for i in range(len(ans)):
    for j in range(len(ans[i])):
        if(isinstance(ans[i][j],int)):
            li += [[]]
n = -1
while(n<len(li)-1):
    for i in range(len(ans)):
        for j in range(len(ans[i])):
            if(isinstance(ans[i][j],int)):
                n = n +1;
            li[n] += ["Level: " + str(ans[i][j])]

# %%
# To convert them in good printing format
lians = []
for i in range(len(li)):
    lians += [[]]
for i in range(len(li)):
    stri = ""
    for j in range(len(li[i])):
        stri += li[i][j]
        stri +="\n" 
    lians[i] += [stri]

# %%
#printing the tree in normal form which all levels are printed groupwise
for i in range(len(li)):
    print(lians[i][0])
# Out:
# Level: 0
# Level: count of 0 =601
# Level: count of 1 =380
# Level: entropy =0.289914344395204
#
# Level: 1
# Level: Is pclass = 3.0?
# Level: --> True:
# Level: count of 0 =394
# Level: count of 1 =138
# Level: entropy =0.24860181025999772
# Level: gain ratio =0.7094098051390281
#
# Level: 1
# Level: Is pclass = 3.0?
# Level: --> False:
# Level: count of 0 =207
# Level: count of 1 =242
# Level: entropy =0.2997091916116832
# Level: gain ratio =0.7094098051390281
#
# Level: 2
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =83
# Level: count of 1 =30
# Level: entropy =0.25133402482143735
# Level: gain ratio =3.2325421359614257
#
# Level: 2
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =249
# Level: count of 1 =170
# Level: entropy =0.29326425193730976
# Level: gain ratio =3.2325421359614257
#
# Level: 2
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =102
# Level: count of 1 =90
# Level: entropy =0.30018121115534735
# Level: gain ratio =3.295629434700096
#
# Level: 2
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =172
# Level: count of 1 =85
# Level: entropy =0.2756471250674296
# Level: gain ratio =3.295629434700096
#
# Level: 3
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =12
# Level: count of 1 =16
# Level: entropy =0.296583221518423
# Level: gain ratio =1.7979833046088225
#
# Level: 3
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =54
# Level: count of 1 =31
# Level: entropy =0.28493097819308383
# Level: gain ratio =1.7979833046088225
#
# Level: 3
# Level: Is FamilySize = 6.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =3
# Level: entropy =0.24421905028821553
# Level: gain ratio =3.253876143453362
#
# Level: 3
# Level: Is FamilySize = 6.0?
# Level: --> False:
# Level: count of 0 =253
# Level: count of 1 =162
# Level: entropy =0.2905037010171815
# Level: gain ratio =3.253876143453362
#
# Level: 3
# Level: Is fare = 0.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =3
# Level: entropy =0.24421905028821553
# Level: gain ratio =2.451632095752773
# Level: Reached leaf node
#
# Level: 3
# Level: Is fare = 0.0?
# Level: --> False:
# Level: count of 0 =114
# Level: count of 1 =74
# Level: entropy =0.2911243369634132
# Level: gain ratio =2.451632095752773
#
# Level: 3
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =34
# Level: count of 1 =12
# Level: entropy =0.24926961142052684
# Level: gain ratio =2.837972253084021
#
# Level: 3
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =121
# Level: count of 1 =90
# Level: entropy =0.2963257934122438
# Level: gain ratio =2.837972253084021
#
# Level: 4
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =4
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.7479716393866527
#
# Level: 4
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =14
# Level: count of 1 =9
# Level: entropy =0.2906854410415382
# Level: gain ratio =0.7479716393866527
#
# Level: 4
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =11
# Level: count of 1 =14
# Level: entropy =0.29789552722260526
# Level: gain ratio =1.4987252020957151
#
# Level: 4
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =36
# Level: count of 1 =24
# Level: entropy =0.29228525323862886
# Level: gain ratio =1.4987252020957151
#
# Level: 4
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 4
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 4
# Level: Is embarked = 0.0?
# Level: --> True:
# Level: count of 0 =177
# Level: count of 1 =129
# Level: entropy =0.2956647572834006
# Level: gain ratio =3.25533973457356
#
# Level: 4
# Level: Is embarked = 0.0?
# Level: --> False:
# Level: count of 0 =74
# Level: count of 1 =35
# Level: entropy =0.2726051326896889
# Level: gain ratio =3.25533973457356
#
# Level: 4
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =34
# Level: count of 1 =16
# Level: entropy =0.27224594629738935
# Level: gain ratio =2.421778077331488
#
# Level: 4
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =77
# Level: count of 1 =61
# Level: entropy =0.29810440687994744
# Level: gain ratio =2.421778077331488
#
# Level: 4
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =12
# Level: count of 1 =6
# Level: entropy =0.27643459094367495
# Level: gain ratio =1.0133138312200436
#
# Level: 4
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =13
# Level: count of 1 =15
# Level: entropy =0.2999211575627872
# Level: gain ratio =1.0133138312200436
#
# Level: 4
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =65
# Level: count of 1 =34
# Level: entropy =0.27937608993873897
# Level: gain ratio =2.576519765206665
#
# Level: 4
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =61
# Level: count of 1 =51
# Level: entropy =0.29929660377150713
# Level: gain ratio =2.576519765206665
#
# Level: 5
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 5
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 5
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =5
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.6671460576544932
#
# Level: 5
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =10
# Level: count of 1 =6
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.6671460576544932
#
# Level: 5
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =4
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.6999162521098828
#
# Level: 5
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =12
# Level: count of 1 =8
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.6999162521098828
#
# Level: 5
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =12
# Level: count of 1 =15
# Level: entropy =0.2983436219957756
# Level: gain ratio =1.2046170820158963
#
# Level: 5
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =24
# Level: count of 1 =9
# Level: entropy =0.2544759887859944
# Level: gain ratio =1.2046170820158963
#
# Level: 5
# Level: Is fare = 1.0?
# Level: --> True:
# Level: count of 0 =85
# Level: count of 1 =40
# Level: entropy =0.27224594629738935
# Level: gain ratio =3.0420431896080977
#
# Level: 5
# Level: Is fare = 1.0?
# Level: --> False:
# Level: count of 0 =99
# Level: count of 1 =82
# Level: entropy =0.2991116126558021
# Level: gain ratio =3.0420431896080977
#
# Level: 5
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =36
# Level: count of 1 =31
# Level: entropy =0.2998195409622474
# Level: gain ratio =1.7521549622375538
#
# Level: 5
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =26
# Level: count of 1 =16
# Level: entropy =0.2886010339756132
# Level: gain ratio =1.7521549622375538
#
# Level: 5
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =3
# Level: entropy =0.27643459094367495
# Level: gain ratio =1.0673198551209093
#
# Level: 5
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =22
# Level: count of 1 =19
# Level: entropy =0.2998663592516309
# Level: gain ratio =1.0673198551209093
#
# Level: 5
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =18
# Level: count of 1 =21
# Level: entropy =0.2997438305836322
# Level: gain ratio =2.033175400049098
#
# Level: 5
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =64
# Level: count of 1 =35
# Level: entropy =0.2821210543225153
# Level: gain ratio =2.033175400049098
#
# Level: 5
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =4
# Level: entropy =0.2846721173935298
# Level: gain ratio =0.5834211774215886
#
# Level: 5
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =5
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.5834211774215886
#
# Level: 5
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =9
# Level: count of 1 =3
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.7486333607941373
#
# Level: 5
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =10
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.7486333607941373
#
# Level: 5
# Level: Is embarked = 0.0?
# Level: --> True:
# Level: count of 0 =24
# Level: count of 1 =32
# Level: entropy =0.296583221518423
# Level: gain ratio =1.6575265513429946
#
# Level: 5
# Level: Is embarked = 0.0?
# Level: --> False:
# Level: count of 0 =30
# Level: count of 1 =13
# Level: entropy =0.2661451713568248
# Level: gain ratio =1.6575265513429946
#
# Level: 5
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =14
# Level: count of 1 =4
# Level: entropy =0.23004847928068484
# Level: gain ratio =1.7876649482528826
#
# Level: 5
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =51
# Level: count of 1 =43
# Level: entropy =0.29945527305802866
# Level: gain ratio =1.7876649482528826
#
# Level: 6
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.40207823261175457
# Level: Reached leaf node
#
# Level: 6
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.40207823261175457
# Level: Reached leaf node
#
# Level: 6
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =6
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.5492325495987298
#
# Level: 6
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =2
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.5492325495987298
#
# Level: 6
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 6
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 6
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =2
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.6171884653350107
# Level: Reached leaf node
#
# Level: 6
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =8
# Level: entropy =0.2893610509517873
# Level: gain ratio =0.6171884653350107
#
# Level: 6
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =8
# Level: count of 1 =2
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.7334667455875343
#
# Level: 6
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =11
# Level: entropy =0.28196497790519526
# Level: gain ratio =0.7334667455875343
#
# Level: 6
# Level: Is FamilySize = 6.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =1
# Level: entropy =0.16362920197946884
# Level: gain ratio =0.8269196226802819
#
# Level: 6
# Level: Is FamilySize = 6.0?
# Level: --> False:
# Level: count of 0 =11
# Level: count of 1 =14
# Level: entropy =0.29789552722260526
# Level: gain ratio =0.8269196226802819
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =51
# Level: count of 1 =43
# Level: entropy =0.29945527305802866
# Level: gain ratio =1.9148542061115812
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =23
# Level: count of 1 =8
# Level: entropy =0.24799201240394408
# Level: gain ratio =1.9148542061115812
#
# Level: 6
# Level: Is FamilySize = 7.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =8
# Level: entropy =0.2544759887859944
# Level: gain ratio =2.3782357838800934
#
# Level: 6
# Level: Is FamilySize = 7.0?
# Level: --> False:
# Level: count of 0 =104
# Level: count of 1 =66
# Level: entropy =0.2900879388321769
# Level: gain ratio =2.3782357838800934
#
# Level: 6
# Level: Is age = 0.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =3
# Level: entropy =0.29228525323862886
# Level: gain ratio =1.2867394675020063
#
# Level: 6
# Level: Is age = 0.0?
# Level: --> False:
# Level: count of 0 =36
# Level: count of 1 =26
# Level: entropy =0.29535625280690536
# Level: gain ratio =1.2867394675020063
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =23
# Level: count of 1 =15
# Level: entropy =0.2913333567683929
# Level: gain ratio =0.9568643546473707
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =4
# Level: entropy =0
# Level: gain ratio =0.9568643546473707
#
# Level: 6
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.4299744410916737
# Level: Reached leaf node
#
# Level: 6
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.4299744410916737
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =10
# Level: count of 1 =3
# Level: entropy =0.23460767814076078
# Level: gain ratio =0.9445648266069196
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =12
# Level: count of 1 =16
# Level: entropy =0.296583221518423
# Level: gain ratio =0.9445648266069196
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =8
# Level: entropy =0.296583221518423
# Level: gain ratio =0.9132640577180328
#
# Level: 6
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =15
# Level: count of 1 =10
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.9132640577180328
#
# Level: 6
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =10
# Level: count of 1 =3
# Level: entropy =0.23460767814076078
# Level: gain ratio =1.651865903185071
#
# Level: 6
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =44
# Level: count of 1 =42
# Level: entropy =0.30091254470747386
# Level: gain ratio =1.651865903185071
#
# Level: 6
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4623898530505439
# Level: Reached leaf node
#
# Level: 6
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =4
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.4623898530505439
#
# Level: 6
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.402210281499661
#
# Level: 6
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.402210281499661
# Level: Reached leaf node
#
# Level: 6
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4795734770546406
# Level: Reached leaf node
#
# Level: 6
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =7
# Level: count of 1 =4
# Level: entropy =0.2846721173935298
# Level: gain ratio =0.4795734770546406
#
# Level: 6
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =6
# Level: entropy =0.2997438305836322
# Level: gain ratio =0.5484103928728944
#
# Level: 6
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.5484103928728944
#
# Level: 6
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =31
# Level: count of 1 =18
# Level: entropy =0.28556102695255525
# Level: gain ratio =1.149234317943044
#
# Level: 6
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =4
# Level: entropy =0.296583221518423
# Level: gain ratio =1.149234317943044
#
# Level: 6
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =11
# Level: count of 1 =13
# Level: entropy =0.2995202785145496
# Level: gain ratio =0.9707453814832824
#
# Level: 6
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =12
# Level: count of 1 =7
# Level: entropy =0.28581353607539234
# Level: gain ratio =0.9707453814832824
#
# Level: 6
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =7
# Level: entropy =0.2949698875659671
# Level: gain ratio =0.5829032666712504
#
# Level: 6
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.5829032666712504
#
# Level: 6
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =20
# Level: entropy =0.2485383495893791
# Level: gain ratio =1.6113424212521876
#
# Level: 6
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =44
# Level: count of 1 =23
# Level: entropy =0.27933363861430577
# Level: gain ratio =1.6113424212521876
#
# Level: 7
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =1
# Level: entropy =0.1956762467702946
# Level: gain ratio =0.43063768594438967
# Level: Reached leaf node
#
# Level: 7
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.43063768594438967
# Level: Reached leaf node
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.40241297178855523
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.40241297178855523
#
# Level: 7
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4964699832320515
# Level: Reached leaf node
#
# Level: 7
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =6
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4964699832320515
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4459363042364095
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =3
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4459363042364095
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =4
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.5661477947176021
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =5
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.5661477947176021
#
# Level: 7
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.4150505329368685
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =2
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4150505329368685
#
# Level: 7
# Level: Is FamilySize = 4.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.6995848191876056
#
# Level: 7
# Level: Is FamilySize = 4.0?
# Level: --> False:
# Level: count of 0 =9
# Level: count of 1 =11
# Level: entropy =0.2988548895792612
# Level: gain ratio =0.6995848191876056
#
# Level: 7
# Level: Is age = 0.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =1.5951434955011339
# Level: Reached leaf node
#
# Level: 7
# Level: Is age = 0.0?
# Level: --> False:
# Level: count of 0 =50
# Level: count of 1 =41
# Level: entropy =0.29890250943856506
# Level: gain ratio =1.5951434955011339
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =3
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.7937279129037291
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =15
# Level: count of 1 =12
# Level: entropy =0.2983436219957756
# Level: gain ratio =0.7937279129037291
#
# Level: 7
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =4
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.4623898530505439
#
# Level: 7
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4623898530505439
# Level: Reached leaf node
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =3
# Level: entropy =0
# Level: gain ratio =2.288608601532368
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =100
# Level: count of 1 =67
# Level: entropy =0.29249484371671275
# Level: gain ratio =2.288608601532368
#
# Level: 7
# Level: Is fare = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 7
# Level: Is fare = 1.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 7
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =9
# Level: count of 1 =10
# Level: entropy =0.30042820174472773
# Level: gain ratio =1.2267541455046733
#
# Level: 7
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =28
# Level: count of 1 =15
# Level: entropy =0.28086860061639213
# Level: gain ratio =1.2267541455046733
#
# Level: 7
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =11
# Level: count of 1 =13
# Level: entropy =0.2995202785145496
# Level: gain ratio =0.8997798802592469
#
# Level: 7
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =10
# Level: count of 1 =4
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.8997798802592469
#
# Level: 7
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 7
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.49738531336255254
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =5
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.49738531336255254
#
# Level: 7
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =4
# Level: entropy =0.296583221518423
# Level: gain ratio =0.7465333207591033
# Level: Reached leaf node
#
# Level: 7
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =12
# Level: count of 1 =9
# Level: entropy =0.296583221518423
# Level: gain ratio =0.7465333207591033
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =4
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5139962686547342
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.5139962686547342
#
# Level: 7
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =11
# Level: count of 1 =7
# Level: entropy =0.2902166263899575
# Level: gain ratio =0.699637872341739
#
# Level: 7
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =5
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.699637872341739
#
# Level: 7
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.496580905311079
#
# Level: 7
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =5
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.496580905311079
#
# Level: 7
# Level: Is FamilySize = 6.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =1.5082540279416548
# Level: Reached leaf node
#
# Level: 7
# Level: Is FamilySize = 6.0?
# Level: --> False:
# Level: count of 0 =44
# Level: count of 1 =38
# Level: entropy =0.2998663592516309
# Level: gain ratio =1.5082540279416548
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.446300157816263
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =3
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.446300157816263
#
# Level: 7
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.3936395446599453
# Level: Reached leaf node
#
# Level: 7
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.3936395446599453
# Level: Reached leaf node
#
# Level: 7
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =2
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4622789628769931
#
# Level: 7
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =3
# Level: entropy =0.296583221518423
# Level: gain ratio =0.4622789628769931
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.4968953054835638
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =5
# Level: entropy =0.2983436219957756
# Level: gain ratio =0.4968953054835638
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 7
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
#
# Level: 7
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =18
# Level: count of 1 =11
# Level: entropy =0.2882523210506807
# Level: gain ratio =1.0543209894111785
#
# Level: 7
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =9
# Level: count of 1 =11
# Level: entropy =0.2988548895792612
# Level: gain ratio =1.0543209894111785
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.40241297178855523
# Level: Reached leaf node
#
# Level: 7
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.40241297178855523
#
# Level: 7
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =5
# Level: entropy =0.2949698875659671
# Level: gain ratio =0.6825961588521482
#
# Level: 7
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =7
# Level: entropy =0.2949698875659671
# Level: gain ratio =0.6825961588521482
#
# Level: 7
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =8
# Level: entropy =0.296583221518423
# Level: gain ratio =0.6004228319408282
#
# Level: 7
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.6004228319408282
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4793966483422553
# Level: Reached leaf node
#
# Level: 7
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =4
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.4793966483422553
# Level: Reached leaf node
#
# Level: 7
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.3933995916565733
# Level: Reached leaf node
#
# Level: 7
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.3933995916565733
# Level: Reached leaf node
#
# Level: 7
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =8
# Level: count of 1 =3
# Level: entropy =0.2544759887859944
# Level: gain ratio =0.732330949779351
#
# Level: 7
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =10
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.732330949779351
#
# Level: 7
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =25
# Level: count of 1 =15
# Level: entropy =0.28731326376205835
# Level: gain ratio =1.2875233673882147
#
# Level: 7
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =13
# Level: count of 1 =14
# Level: entropy =0.30073205751142396
# Level: gain ratio =1.2875233673882147
#
# Level: 8
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.42974552513914027
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =3
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.42974552513914027
# Level: Reached leaf node
#
# Level: 8
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4457419542814002
# Level: Reached leaf node
#
# Level: 8
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =3
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.4457419542814002
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 5.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =2
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.40203179978677983
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 5.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.40203179978677983
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4165198575453182
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4165198575453182
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =7
# Level: entropy =0.2652949955741215
# Level: gain ratio =0.6177962341612385
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =7
# Level: count of 1 =3
# Level: entropy =0.2652949955741215
# Level: gain ratio =0.6177962341612385
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =1.5627522091555708
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =50
# Level: count of 1 =40
# Level: entropy =0.2983436219957756
# Level: gain ratio =1.5627522091555708
#
# Level: 8
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
#
# Level: 8
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =8
# Level: count of 1 =10
# Level: entropy =0.2983436219957756
# Level: gain ratio =0.7311099605457801
#
# Level: 8
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =3
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.7311099605457801
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4456034007828225
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =4
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4456034007828225
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =22
# Level: count of 1 =9
# Level: entropy =0.2616364821232255
# Level: gain ratio =2.2676097762366583
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =76
# Level: count of 1 =60
# Level: entropy =0.2980175257499325
# Level: gain ratio =2.2676097762366583
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5995166625125501
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =10
# Level: count of 1 =8
# Level: entropy =0.2983436219957756
# Level: gain ratio =0.5995166625125501
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =2
# Level: entropy =0
# Level: gain ratio =0.9701368414323442
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =23
# Level: count of 1 =18
# Level: entropy =0.2977925074450002
# Level: gain ratio =0.9701368414323442
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.6823902049485451
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =10
# Level: count of 1 =12
# Level: entropy =0.2992329102507745
# Level: gain ratio =0.6823902049485451
#
# Level: 8
# Level: Is fare = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5140242099858494
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 1.0?
# Level: --> False:
# Level: count of 0 =8
# Level: count of 1 =5
# Level: entropy =0.2893610509517873
# Level: gain ratio =0.5140242099858494
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 8
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 8
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 8
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =1
# Level: entropy =0.1956762467702946
# Level: gain ratio =0.4156786567897574
# Level: Reached leaf node
#
# Level: 8
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =2
# Level: entropy =0
# Level: gain ratio =0.4156786567897574
# Level: Reached leaf node
#
# Level: 8
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.6334605613180613
# Level: Reached leaf node
#
# Level: 8
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =8
# Level: count of 1 =9
# Level: entropy =0.3002781872083049
# Level: gain ratio =0.6334605613180613
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =3
# Level: entropy =0.296583221518423
# Level: gain ratio =0.41477846401879376
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.41477846401879376
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =2
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.39335420765642476
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39335420765642476
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =9
# Level: entropy =0.2976281785900671
# Level: gain ratio =0.5826034026592789
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5826034026592789
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 5.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4029002651346722
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 5.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =1
# Level: entropy =0.1956762467702946
# Level: gain ratio =0.4029002651346722
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =3
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4459363042364095
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4459363042364095
# Level: Reached leaf node
#
# Level: 8
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =32
# Level: count of 1 =28
# Level: entropy =0.30006418065332474
# Level: gain ratio =1.4638582412233407
#
# Level: 8
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =14
# Level: count of 1 =8
# Level: entropy =0.2846721173935298
# Level: gain ratio =1.4638582412233407
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 8
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4025803021264083
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.4025803021264083
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =2
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.4302712424426356
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4302712424426356
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 2.0?
# Level: --> True:
# Level: count of 0 =8
# Level: count of 1 =10
# Level: entropy =0.2983436219957756
# Level: gain ratio =0.7625039016153942
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 2.0?
# Level: --> False:
# Level: count of 0 =7
# Level: count of 1 =4
# Level: entropy =0.2846721173935298
# Level: gain ratio =0.7625039016153942
#
# Level: 8
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =8
# Level: entropy =0.2893610509517873
# Level: gain ratio =0.6171884653350107
#
# Level: 8
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =2
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.6171884653350107
#
# Level: 8
# Level: Is FamilySize = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 8
# Level: Is FamilySize = 4.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =4
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.4793966483422553
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4793966483422553
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4795734770546406
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =7
# Level: count of 1 =4
# Level: entropy =0.2846721173935298
# Level: gain ratio =0.4795734770546406
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =3
# Level: entropy =0.2652949955741215
# Level: gain ratio =0.514797538708808
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =3
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.514797538708808
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 8
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.39373831991943087
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4623898530505439
# Level: Reached leaf node
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =4
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.4623898530505439
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =6
# Level: count of 1 =5
# Level: entropy =0.2992329102507745
# Level: gain ratio =0.5483574210943932
#
# Level: 8
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =3
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.5483574210943932
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =16
# Level: count of 1 =18
# Level: entropy =0.3002781872083049
# Level: gain ratio =0.9290227807215173
#
# Level: 8
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =1
# Level: entropy =0.1956762467702946
# Level: gain ratio =0.9290227807215173
#
# Level: 8
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =10
# Level: count of 1 =11
# Level: entropy =0.3005374120319918
# Level: gain ratio =0.7308144035140441
#
# Level: 8
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.7308144035140441
#
# Level: 9
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4459363042364095
# Level: Reached leaf node
#
# Level: 9
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =3
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4459363042364095
#
# Level: 9
# Level: Is FamilySize = 5.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.44573432183404277
# Level: Reached leaf node
#
# Level: 9
# Level: Is FamilySize = 5.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =3
# Level: entropy =0.296583221518423
# Level: gain ratio =0.44573432183404277
#
# Level: 9
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =34
# Level: count of 1 =29
# Level: entropy =0.2996607856677658
# Level: gain ratio =1.552093799532032
# Level: Reached leaf node
#
# Level: 9
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =16
# Level: count of 1 =11
# Level: entropy =0.29354008789101427
# Level: gain ratio =1.552093799532032
#
# Level: 9
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 9
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 9
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5830615750725547
# Level: Reached leaf node
#
# Level: 9
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =9
# Level: entropy =0.2830542780615224
# Level: gain ratio =0.5830615750725547
#
# Level: 9
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.43000107543396365
# Level: Reached leaf node
#
# Level: 9
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =2
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.43000107543396365
#
# Level: 9
# Level: Is age = 0.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =3
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.7932073639315526
#
# Level: 9
# Level: Is age = 0.0?
# Level: --> False:
# Level: count of 0 =11
# Level: count of 1 =12
# Level: entropy =0.30061937996055055
# Level: gain ratio =0.7932073639315526
#
# Level: 9
# Level: Is age = 1.0?
# Level: --> True:
# Level: count of 0 =60
# Level: count of 1 =36
# Level: entropy =0.28731326376205835
# Level: gain ratio =2.010793092299051
#
# Level: 9
# Level: Is age = 1.0?
# Level: --> False:
# Level: count of 0 =21
# Level: count of 1 =19
# Level: entropy =0.30048690114006105
# Level: gain ratio =2.010793092299051
#
# Level: 9
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =8
# Level: count of 1 =9
# Level: entropy =0.3002781872083049
# Level: gain ratio =0.5824932470515023
# Level: Reached leaf node
#
# Level: 9
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5824932470515023
# Level: Reached leaf node
#
# Level: 9
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =22
# Level: count of 1 =18
# Level: entropy =0.2988548895792612
# Level: gain ratio =0.9414864750223093
# Level: Reached leaf node
#
# Level: 9
# Level: Is IsAlone = 1.0?
# Level: --> False:
# ...
# Level: Reached leaf node
#
# Level: 10
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =2
# Level: entropy =0.24421905028821553
# Level: gain ratio =1.6178501756768442
# Level: Reached leaf node
#
# Level: 10
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =17
# Level: count of 1 =10
# Level: entropy =0.28626629514303703
# Level: gain ratio =0.9295994925651659
#
# Level: 10
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =9
# Level: entropy =0.268064694594085
# Level: gain ratio =0.9295994925651659
#
# Level: 10
# Level: Is FamilySize = 6.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 10
# Level: Is FamilySize = 6.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 10
# Level: Is FamilySize = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 10
# Level: Is FamilySize = 4.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 10
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =5
# Level: entropy =0.1956762467702946
# Level: gain ratio =1.112277712944978
#
# Level: 10
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =30
# Level: count of 1 =17
# Level: entropy =0.284198511020387
# Level: gain ratio =1.112277712944978
#
# Level: 10
# Level: Is FamilySize = 4.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.40207823261175457
#
# Level: 10
# Level: Is FamilySize = 4.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.40207823261175457
#
# Level: 10
# Level: Is FamilySize = 3.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5656974126018595
# Level: Reached leaf node
#
# Level: 10
# Level: Is FamilySize = 3.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =9
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.5656974126018595
#
# Level: 10
# Level: Is FamilySize = 6.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4149333652853543
# Level: Reached leaf node
#
# Level: 10
# Level: Is FamilySize = 6.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4149333652853543
# Level: Reached leaf node
#
# Level: 10
# Level: Is pclass = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 10
# Level: Is pclass = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 10
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 10
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 10
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4457419542814002
# Level: Reached leaf node
#
# Level: 10
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =3
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.4457419542814002
# Level: Reached leaf node
#
# Level: 10
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 10
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 10
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.42974552513914027
# Level: Reached leaf node
#
# Level: 10
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =3
# Level: entropy =0.28731326376205835
# Level: gain ratio =0.42974552513914027
#
# Level: 10
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =2
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.4458018687241752
# Level: Reached leaf node
#
# Level: 10
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4458018687241752
# Level: Reached leaf node
#
# Level: 10
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 10
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
#
# Level: 10
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =5
# Level: count of 1 =2
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.7937996579818876
#
# Level: 10
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =11
# Level: count of 1 =13
# Level: entropy =0.2995202785145496
# Level: gain ratio =0.7937996579818876
#
# Level: 10
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 10
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.39373831991943087
#
# Level: 10
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =3
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.46254234189986737
# Level: Reached leaf node
#
# Level: 10
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.46254234189986737
#
# Level: 10
# Level: Is embarked = 1.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.44573432183404277
#
# Level: 10
# Level: Is embarked = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =3
# Level: entropy =0.296583221518423
# Level: gain ratio =0.44573432183404277
# Level: Reached leaf node
#
# Level: 11
# Level: Is FamilySize = 5.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.40207823261175457
# Level: Reached leaf node
#
# Level: 11
# Level: Is FamilySize = 5.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.40207823261175457
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.43019947530402425
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =2
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.43019947530402425
# Level: Reached leaf node
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =5
# Level: entropy =0.2983436219957756
# Level: gain ratio =0.5145374109422556
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.5145374109422556
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =13
# Level: count of 1 =13
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.7304263054404239
# Level: Reached leaf node
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.7304263054404239
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 0.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =4
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.49652769699328975
#
# Level: 11
# Level: Is age = 0.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.49652769699328975
#
# Level: 11
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.3939212620188948
# Level: Reached leaf node
#
# Level: 11
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.3939212620188948
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =1.0258084958584508
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =25
# Level: count of 1 =20
# Level: entropy =0.2983436219957756
# Level: gain ratio =1.0258084958584508
#
# Level: 11
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 3.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39348414120425745
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 3.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.39348414120425745
# Level: Reached leaf node
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =7
# Level: count of 1 =5
# Level: entropy =0.2949698875659671
# Level: gain ratio =0.5312801312644392
# Level: Reached leaf node
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.5312801312644392
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4151568681974367
# Level: Reached leaf node
#
# Level: 11
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =5
# Level: count of 1 =2
# Level: entropy =0.25982518101310587
# Level: gain ratio =0.4151568681974367
# Level: Reached leaf node
#
# Level: 11
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 11
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =infinite
# Level: Reached leaf node
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =3
# Level: count of 1 =2
# Level: entropy =0.29228525323862886
# Level: gain ratio =0.40207823261175457
# Level: Reached leaf node
#
# Level: 11
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.40207823261175457
# Level: Reached leaf node
#
# Level: 11
# Level: Is Has_Cabin = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =2
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.6824452486761677
# Level: Reached leaf node
#
# Level: 11
# Level: Is Has_Cabin = 1.0?
# Level: --> False:
# Level: count of 0 =11
# Level: count of 1 =10
# Level: entropy =0.3005374120319918
# Level: gain ratio =0.6824452486761677
#
# Level: 11
# Level: Is fare = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.4166120232031104
#
# Level: 11
# Level: Is fare = 2.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.4166120232031104
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.3939212620188948
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =1
# Level: entropy =0.21732201127364886
# Level: gain ratio =0.3939212620188948
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 11
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.5346226168533992
# Level: Reached leaf node
#
# Level: 12
# Level: Is age = 3.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.4302712424426356
# Level: Reached leaf node
#
# Level: 12
# Level: Is age = 3.0?
# Level: --> False:
# Level: count of 0 =6
# Level: count of 1 =2
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.4302712424426356
#
# Level: 12
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =2
# Level: count of 1 =1
# Level: entropy =0.27643459094367495
# Level: gain ratio =0.39354037675017295
#
# Level: 12
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =2
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39354037675017295
# Level: Reached leaf node
#
# Level: 12
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =4
# Level: count of 1 =3
# Level: entropy =0.296583221518423
# Level: gain ratio =0.41477846401879376
# Level: Reached leaf node
#
# Level: 12
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.41477846401879376
# Level: Reached leaf node
#
# Level: 12
# Level: Is age = 4.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 12
# Level: Is age = 4.0?
# Level: --> False:
# Level: count of 0 =3
# Level: count of 1 =1
# Level: entropy =0.24421905028821553
# Level: gain ratio =0.39373831991943087
# Level: Reached leaf node
#
# Level: 12
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.9979789006708518
# Level: Reached leaf node
#
# Level: 12
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =24
# Level: count of 1 =20
# Level: entropy =0.2992329102507745
# Level: gain ratio =0.9979789006708518
# Level: Reached leaf node
#
# Level: 12
# Level: Is embarked = 2.0?
# Level: --> True:
# Level: count of 0 =0
# Level: count of 1 =1
# Level: entropy =0
# Level: gain ratio =0.6330385793447761
# Level: Reached leaf node
#
# Level: 12
# Level: Is embarked = 2.0?
# Level: --> False:
# Level: count of 0 =11
# Level: count of 1 =9
# Level: entropy =0.2988548895792612
# Level: gain ratio =0.6330385793447761
# Level: Reached leaf node
#
# Level: 12
# Level: Is IsAlone = 1.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 12
# Level: Is IsAlone = 1.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 13
# Level: Is age = 2.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.41477846401879376
# Level: Reached leaf node
#
# Level: 13
# Level: Is age = 2.0?
# Level: --> False:
# Level: count of 0 =4
# Level: count of 1 =3
# Level: entropy =0.296583221518423
# Level: gain ratio =0.41477846401879376
# Level: Reached leaf node
#
# Level: 13
# Level: Is FamilySize = 5.0?
# Level: --> True:
# Level: count of 0 =1
# Level: count of 1 =0
# Level: entropy =0
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node
#
# Level: 13
# Level: Is FamilySize = 5.0?
# Level: --> False:
# Level: count of 0 =1
# Level: count of 1 =1
# Level: entropy =0.30102999566398114
# Level: gain ratio =0.5345806985518538
# Level: Reached leaf node

# %%
# To make list easy to print levels in form of tree and find the no. of each level
li = []
dic = {}
n = 0
for i in range(len(ans)):
    for j in range(len(ans[i])):
        if(ans[i][j] == n):
            li += [[]]
            n = n + 1

for i in range(len(ans)):
    for j in range(len(ans[i])):
        if(isinstance (ans[i][j],int)):
            n = ans[i][j]
            li[n] += [[]]
for i in range(len(ans)):
    count = 0
    k = -1
    for j in range(len(ans[i])):
        if(isinstance (ans[i][j],int)):
            n = ans[i][j]
            count += 1
            dic[ans[i][j]] = count
            ans[i][j] = "level: " + str(ans[i][j])
            k = k + 1
        li[n][k] += [ans[i][j] ]
dic
# Out:
# {0: 1,
#  1: 2,
#  2: 4,
#  3: 8,
#  4: 14,
#  5: 24,
#  6: 44,
#  7: 70,
#  8: 90,
#  9: 64,
#  10: 52,
#  11: 34,
#  12: 14,
#  13: 4}

# %%
# To convert list li in a good format to print
lians = []
for i in range(len(li)):
    lians += [[]]
    for j in range(len(li[i])):
        lians[i] += [[]]
strl =""
for i in range(len(li)):
    for j in range(len(li[i])):
        stri = ""
        strl = ""
        for l in range(60//dic[i]):
            strl += " "
        for k in range(1):
            stri = stri + strl + li[i][j][k]
        
        lians[i][j] += [stri]

# %%
#printing the tree till level 3 in tree form
for i in range(4):
    for j in range(len(li[i])):
        print(lians[i][j][0], end = "")
    print("\n")
    print("\n")
# Out:
#                                                             level: 0
#
#
#
#                               level: 1                              level: 1
#
#
#
#                level: 2               level: 2               level: 2               level: 2
#
#
#
#        level: 3       level: 3       level: 3       level: 3       level: 3       level: 3       level: 3       level: 3

# %%
#printing tree spaced according to the level in tree  type format
print_tree(my_tree)
# Out:
# 1
# Is pclass = 3.0?
# --> True:
# count of 0 = 394
# count of 1 = 138
# entropy = 0.24860181025999772
# gain ratio = 0.7094098051390281
#       2
#       Is fare = 2.0?
#       --> True:
#       count of 0 = 83
#       count of 1 = 30
#       entropy = 0.25133402482143735
#       gain ratio = 3.2325421359614257
#             3
#             Is embarked = 1.0?
#             --> True:
#             count of 0 = 12
#             count of 1 = 16
#             entropy = 0.296583221518423
#             gain ratio = 1.7979833046088225
#                   4
#                   Is age = 2.0?
#                   --> True:
#                   count of 0 = 1
#                   count of 1 = 4
#                   entropy = 0.21732201127364886
#                   gain ratio = 0.7479716393866527
#                         5
#                         Is FamilySize = 3.0?
#                         --> True:
#                         count of 0 = 2
#                         count of 1 = 1
#                         entropy = 0.27643459094367495
#                         gain ratio = 0.39354037675017295
#                               reached node leaf
#                         5
#                         Is FamilySize = 3.0?
#                         --> False:
#                         count of 0 = 2
#                         count of 1 = 0
#                         entropy = 0
#                         gain ratio = 0.39354037675017295
#                               reached node leaf
#                   4
#                   Is age = 2.0?
#                   --> False:
#                   count of 0 = 14
#                   count of 1 = 9
#                   entropy = 0.2906854410415382
#                   gain ratio = 0.7479716393866527
#                         5
#                         Is FamilySize = 2.0?
#                         --> True:
#                         count of 0 = 2
#                         count of 1 = 5
#                         entropy = 0.25982518101310587
#                         gain ratio = 0.6671460576544932
#                               6
#                               Is age = 1.0?
#                               --> True:
#                               count of 0 = 3
#                               count of 1 = 2
#                               entropy = 0.29228525323862886
#                               gain ratio = 0.40207823261175457
#                                     reached node leaf
#                               6
#                               Is age = 1.0?
#                               --> False:
#                               count of 0 = 2
#                               count of 1 = 0
#                               entropy = 0
#                               gain ratio = 0.40207823261175457
#                                     reached node leaf
#                         5
#                         Is FamilySize = 2.0?
#                         --> False:
#                         count of 0 = 10
#                         count of 1 = 6
#                         entropy = 0.28731326376205835
#                         gain ratio = 0.6671460576544932
#                               6
#                               Is FamilySize = 3.0?
#                               --> True:
#                               count of 0 = 3
#                               count of 1 = 6
#                               entropy = 0.27643459094367495
#                               gain ratio = 0.5492325495987298
#                                     7
#                                     Is age = 1.0?
#                                     --> True:
#                                     count of 0 = 5
#                                     count of 1 = 1
#                                     entropy = 0.1956762467702946
#                                     gain ratio = 0.43063768594438967
#                                           reached node leaf
#                                     7
#                                     Is age = 1.0?
#                                     --> False:
#                                     count of 0 = 1
#                                     count of 1 = 2
#                                     entropy = 0.27643459094367495
#                                     gain ratio = 0.43063768594438967
#                                           reached node leaf
#                               6
#                               Is FamilySize = 3.0?
#                               --> False:
#                               count of 0 = 5
#                               count of 1 = 2
#                               entropy = 0.25982518101310587
#                               gain ratio = 0.5492325495987298
#                                     7
#                                     Is IsAlone = 1.0?
#                                     --> True:
#                                     count of 0 = 3
#                                     count of 1 = 1
#                                     entropy = 0.24421905028821553
#                                     gain ratio = 0.40241297178855523
#                                           8
#                                           Is age = 1.0?
#                                           --> True:
#                                           count of 0 = 2
#                                           count of 1 = 1
#                                           entropy = 0.27643459094367495
#                                           gain ratio = 0.4166120232031104
#                                                 reached node leaf
#                                           8
#                                           Is age = 1.0?
#                                           --> False:
#                                           count of 0 = 1
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.4166120232031104
#                                                 reached node leaf
#                                     7
#                                     Is IsAlone = 1.0?
#                                     --> False:
#                                     count of 0 = 2
#                                     count of 1 = 1
#                                     entropy = 0.27643459094367495
#                                     gain ratio = 0.40241297178855523
#                                           8
#                                           Is age = 1.0?
#                                           --> True:
#                                           count of 0 = 1
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.5345806985518538
#                                                 reached node leaf
#                                           8
#                                           Is age = 1.0?
#                                           --> False:
#                                           count of 0 = 1
#                                           count of 1 = 1
#                                           entropy = 0.30102999566398114
#                                           gain ratio = 0.5345806985518538
#                                                 reached node leaf
#             3
#             Is embarked = 1.0?
#             --> False:
#             count of 0 = 54
#             count of 1 = 31
#             entropy = 0.28493097819308383
#             gain ratio = 1.7979833046088225
#                   4
#                   Is FamilySize = 2.0?
#                   --> True:
#                   count of 0 = 11
#                   count of 1 = 14
#                   entropy = 0.29789552722260526
#                   gain ratio = 1.4987252020957151
#                         5
#                         Is embarked = 2.0?
#                         --> True:
#                         count of 0 = 1
#                         count of 1 = 4
#                         entropy = 0.21732201127364886
#                         gain ratio = 0.6999162521098828
#                               6
#                               Is age = 2.0?
#                               --> True:
#                               count of 0 = 2
#                               count of 1 = 0
#                               entropy = 0
#                               gain ratio = 0.39354037675017295
#                                     reached node leaf
#                               6
#                               Is age = 2.0?
#                               --> False:
#                               count of 0 = 2
#                               count of 1 = 1
#                               entropy = 0.27643459094367495
#                               gain ratio = 0.39354037675017295
#                                     reached node leaf
#                         5
#                         Is embarked = 2.0?
#                         --> False:
#                         count of 0 = 12
#                         count of 1 = 8
#                         entropy = 0.29228525323862886
#                         gain ratio = 0.6999162521098828
#                               6
#                               Is age = 2.0?
#                               --> True:
#                               count of 0 = 5
#                               count of 1 = 2
#                               entropy = 0.25982518101310587
#                               gain ratio = 0.6171884653350107
#                                     reached node leaf
#                               6
#                               Is age = 2.0?
#                               --> False:
#                               count of 0 = 5
#                               count of 1 = 8
#                               entropy = 0.2893610509517873
#                               gain ratio = 0.6171884653350107
#                                     7
#                                     Is age = 3.0?
#                                     --> True:
#                                     count of 0 = 1
#                                     count of 1 = 0
#                                     entropy = 0
#                                     gain ratio = 0.4964699832320515
#                                           reached node leaf
#                                     7
#                                     Is age = 3.0?
#                                     --> False:
#                                     count of 0 = 6
#                                     count of 1 = 6
#                                     entropy = 0.30102999566398114
#                                     gain ratio = 0.4964699832320515
#                                           reached node leaf
#                   4
#                   Is FamilySize = 2.0?
#                   --> False:
#                   count of 0 = 36
#                   count of 1 = 24
#                   entropy = 0.29228525323862886
#                   gain ratio = 1.4987252020957151
#                         5
#                         Is age = 1.0?
#                         --> True:
#                         count of 0 = 12
#                         count of 1 = 15
#                         entropy = 0.2983436219957756
#                         gain ratio = 1.2046170820158963
#                               6
#                               Is FamilySize = 3.0?
#                               --> True:
#                               count of 0 = 8
#                               count of 1 = 2
#                               entropy = 0.21732201127364886
#                               gain ratio = 0.7334667455875343
#                                     7
#                                     Is embarked = 2.0?
#                                     --> True:
#                                     count of 0 = 0
#                                     count of 1 = 1
#                                     entropy = 0
#                                     gain ratio = 0.4459363042364095
#                                           reached node leaf
#                                     7
#                                     Is embarked = 2.0?
#                                     --> False:
#                                     count of 0 = 6
#                                     count of 1 = 3
#                                     entropy = 0.27643459094367495
#                                     gain ratio = 0.4459363042364095
#                                           8
#                                           Is Has_Cabin = 1.0?
#                                           --> True:
#                                           count of 0 = 1
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.42974552513914027
#                                                 reached node leaf
#                                           8
#                                           Is Has_Cabin = 1.0?
#                                           --> False:
#                                           count of 0 = 5
#                                           count of 1 = 3
#                                           entropy = 0.28731326376205835
#                                           gain ratio = 0.42974552513914027
#                                                 reached node leaf
#                               6
#                               Is FamilySize = 3.0?
#                               --> False:
#                               count of 0 = 6
#                               count of 1 = 11
#                               entropy = 0.28196497790519526
#                               gain ratio = 0.7334667455875343
#                                     7
#                                     Is IsAlone = 1.0?
#                                     --> True:
#                                     count of 0 = 6
#                                     count of 1 = 4
#                                     entropy = 0.29228525323862886
#                                     gain ratio = 0.5661477947176021
#                                           8
#                                           Is embarked = 2.0?
#                                           --> True:
#                                           count of 0 = 1
#                                           count of 1 = 1
#                                           entropy = 0.30102999566398114
#                                           gain ratio = 0.4457419542814002
#                                                 reached node leaf
#                                           8
#                                           Is embarked = 2.0?
#                                           --> False:
#                                           count of 0 = 5
#                                           count of 1 = 3
#                                           entropy = 0.28731326376205835
#                                           gain ratio = 0.4457419542814002
#                                                 reached node leaf
#                                     7
#                                     Is IsAlone = 1.0?
#                                     --> False:
#                                     count of 0 = 2
#                                     count of 1 = 5
#                                     entropy = 0.25982518101310587
#                                     gain ratio = 0.5661477947176021
#                                           8
#                                           Is FamilySize = 5.0?
#                                           --> True:
#                                           count of 0 = 2
#                                           count of 1 = 2
#                                           entropy = 0.30102999566398114
#                                           gain ratio = 0.40203179978677983
#                                                 reached node leaf
#                                           8
#                                           Is FamilySize = 5.0?
#                                           --> False:
#                                           count of 0 = 3
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.40203179978677983
#                                                 reached node leaf
#                         5
#                         Is age = 1.0?
#                         --> False:
#                         count of 0 = 24
#                         count of 1 = 9
#                         entropy = 0.2544759887859944
#                         gain ratio = 1.2046170820158963
#                               6
#                               Is FamilySize = 6.0?
#                               --> True:
#                               count of 0 = 7
#                               count of 1 = 1
#                               entropy = 0.16362920197946884
#                               gain ratio = 0.8269196226802819
#                                     7
#                                     Is embarked = 2.0?
#                                     --> True:
#                                     count of 0 = 3
#                                     count of 1 = 1
#                                     entropy = 0.24421905028821553
#                                     gain ratio = 0.4150505329368685
#                                           reached node leaf
#                                     7
#                                     Is embarked = 2.0?
#                                     --> False:
#                                     count of 0 = 2
#                                     count of 1 = 2
#                                     entropy = 0.30102999566398114
#                                     gain ratio = 0.4150505329368685
#                                           8
#                                           Is age = 2.0?
#                                           --> True:
#                                           count of 0 = 1
#                                           count of 1 = 1
#                                           entropy = 0.30102999566398114
#                                           gain ratio = 0.4165198575453182
#                                                 reached node leaf
#                                           8
#                                           Is age = 2.0?
#                                           --> False:
#                                           count of 0 = 2
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.4165198575453182
#                                                 reached node leaf
#                               6
#                               Is FamilySize = 6.0?
#                               --> False:
#                               count of 0 = 11
#                               count of 1 = 14
#                               entropy = 0.29789552722260526
#                               gain ratio = 0.8269196226802819
#                                     7
#                                     Is FamilySize = 4.0?
#                                     --> True:
#                                     count of 0 = 4
#                                     count of 1 = 1
#                                     entropy = 0.21732201127364886
#                                     gain ratio = 0.6995848191876056
#                                           8
#                                           Is age = 2.0?
#                                           --> True:
#                                           count of 0 = 2
#                                           count of 1 = 1
#                                           entropy = 0.27643459094367495
#                                           gain ratio = 0.39354037675017295
#                                                 reached node leaf
#                                           8
#                                           Is age = 2.0?
#                                           --> False:
#                                           count of 0 = 2
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.39354037675017295
#                                                 reached node leaf
#                                     7
#                                     Is FamilySize = 4.0?
#                                     --> False:
#                                     count of 0 = 9
#                                     count of 1 = 11
#                                     entropy = 0.2988548895792612
#                                     gain ratio = 0.6995848191876056
#                                           8
#                                           Is age = 2.0?
#                                           --> True:
#                                           count of 0 = 3
#                                           count of 1 = 7
#                                           entropy = 0.2652949955741215
#                                           gain ratio = 0.6177962341612385
#                                                 9
#                                                 Is IsAlone = 1.0?
#                                                 --> True:
#                                                 count of 0 = 0
#                                                 count of 1 = 1
#                                                 entropy = 0
#                                                 gain ratio = 0.4459363042364095
#                                                       reached node leaf
#                                                 9
#                                                 Is IsAlone = 1.0?
#                                                 --> False:
#                                                 count of 0 = 6
#                                                 count of 1 = 3
#                                                 entropy = 0.27643459094367495
#                                                 gain ratio = 0.4459363042364095
#                                                       10
#                                                       Is embarked = 2.0?
#                                                       --> True:
#                                                       count of 0 = 3
#                                                       count of 1 = 0
#                                                       entropy = 0
#                                                       gain ratio = 0.42961209189388955
#                                                             reached node leaf
#                                                       10
#                                                       Is embarked = 2.0?
#                                                       --> False:
#                                                       count of 0 = 3
#                                                       count of 1 = 3
#                                                       entropy = 0.30102999566398114
#                                                       gain ratio = 0.42961209189388955
#                                                             reached node leaf
#                                           8
#                                           Is age = 2.0?
#                                           --> False:
#                                           count of 0 = 7
#                                           count of 1 = 3
#                                           entropy = 0.2652949955741215
#                                           gain ratio = 0.6177962341612385
#                                                 9
#                                                 Is FamilySize = 5.0?
#                                                 --> True:
#                                                 count of 0 = 2
#                                                 count of 1 = 1
#                                                 entropy = 0.27643459094367495
#                                                 gain ratio = 0.44573432183404277
#                                                       reached node leaf
#                                                 9
#                                                 Is FamilySize = 5.0?
#                                                 --> False:
#                                                 count of 0 = 4
#                                                 count of 1 = 3
#                                                 entropy = 0.296583221518423
#                                                 gain ratio = 0.44573432183404277
#                                                       10
#                                                       Is Has_Cabin = 1.0?
#                                                       --> True:
#                                                       count of 0 = 0
#                                                       count of 1 = 1
#                                                       entropy = 0
#                                                       gain ratio = 0.4029002651346722
#                                                             reached node leaf
#                                                       10
#                                                       Is Has_Cabin = 1.0?
#                                                       --> False:
#                                                       count of 0 = 5
#                                                       count of 1 = 1
#                                                       entropy = 0.1956762467702946
#                                                       gain ratio = 0.4029002651346722
#                                                             reached node leaf
#       2
#       Is fare = 2.0?
#       --> False:
#       count of 0 = 249
#       count of 1 = 170
#       entropy = 0.29326425193730976
#       gain ratio = 3.2325421359614257
#             3
#             Is FamilySize = 6.0?
#             --> True:
#             count of 0 = 1
#             count of 1 = 3
#             entropy = 0.24421905028821553
#             gain ratio = 3.253876143453362
#                   4
#                   Is age = 2.0?
#                   --> True:
#                   count of 0 = 1
#                   count of 1 = 0
#                   entropy = 0
#                   gain ratio = 0.4166120232031104
#                         reached node leaf
#                   4
#                   Is age = 2.0?
#                   --> False:
#                   count of 0 = 2
#                   count of 1 = 1
#                   entropy = 0.27643459094367495
#                   gain ratio = 0.4166120232031104
#                         reached node leaf
#             3
#             Is FamilySize = 6.0?
#             --> False:
#             count of 0 = 253
#             count of 1 = 162
#             entropy = 0.2905037010171815
#             gain ratio = 3.253876143453362
#                   4
#                   Is embarked = 0.0?
#                   --> True:
#                   count of 0 = 177
#                   count of 1 = 129
#                   entropy = 0.2956647572834006
#                   gain ratio = 3.25533973457356
#                         5
#                         Is fare = 1.0?
#                         --> True:
#                         count of 0 = 85
#                         count of 1 = 40
#                         entropy = 0.27224594629738935
#                         gain ratio = 3.0420431896080977
#                               6
#                               Is IsAlone = 1.0?
#                               --> True:
#                               count of 0 = 51
#                               count of 1 = 43
#                               entropy = 0.29945527305802866
#                               gain ratio = 1.9148542061115812
#                                     7
#                                     Is age = 0.0?
#                                     --> True:
#                                     count of 0 = 1
#                                     count of 1 = 2
#                                     entropy = 0.27643459094367495
#                                     gain ratio = 1.5951434955011339
#                                           reached node leaf
#                                     7
#                                     Is age = 0.0?
#                                     --> False:
#                                     count of 0 = 50
#                                     count of 1 = 41
#                                     entropy = 0.29890250943856506
#                                     gain ratio = 1.5951434955011339
#                                           8
#                                           Is Has_Cabin = 1.0?
#                                           --> True:
#                                           count of 0 = 0
#                                           count of 1 = 1
#                                           entropy = 0
#                                           gain ratio = 1.5627522091555708
#                                                 reached node leaf
#                                           8
#                                           Is Has_Cabin = 1.0?
#                                           --> False:
#                                           count of 0 = 50
#                                           count of 1 = 40
#                                           entropy = 0.2983436219957756
#                                           gain ratio = 1.5627522091555708
#                                                 9
#                                                 Is age = 1.0?
#                                                 --> True:
#                                                 count of 0 = 34
#                                                 count of 1 = 29
#                                                 entropy = 0.2996607856677658
#                                                 gain ratio = 1.552093799532032
#                                                       reached node leaf
#                                                 9
#                                                 Is age = 1.0?
#                                                 --> False:
#                                                 count of 0 = 16
#                                                 count of 1 = 11
#                                                 entropy = 0.29354008789101427
#                                                 gain ratio = 1.552093799532032
#                                                       10
#                                                       Is age = 3.0?
#                                                       --> True:
#                                                       count of 0 = 2
#                                                       count of 1 = 0
#                                                       entropy = 0
#                                                       gain ratio = 0.7304786609260059
#                                                             reached node leaf
#                                                       10
#                                                       Is age = 3.0?
#                                                       --> False:
#                                                       count of 0 = 12
#                                                       count of 1 = 13
#                                                       entropy = 0.30068246736962256
#                                                       gain ratio = 0.7304786609260059
#                                                             reached node leaf
#                               6
#                               Is IsAlone = 1.0?
#                               --> False:
#                               count of 0 = 23
#                               count of 1 = 8
#                               entropy = 0.24799201240394408
#                               gain ratio = 1.9148542061115812
#                                     7
#                                     Is Has_Cabin = 1.0?
#                                     --> True:
#                                     count of 0 = 1
#                                     count of 1 = 3
#                                     entropy = 0.24421905028821553
#                                     gain ratio = 0.7937279129037291
#                                           8
#                                           Is FamilySize = 3.0?
#                                           --> True:
#                                           count of 0 = 1
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.4166120232031104
#                                                 reached node leaf
#                                           8
#                                           Is FamilySize = 3.0?
#                                           --> False:
#                                           count of 0 = 2
#                                           count of 1 = 1
#                                           entropy = 0.27643459094367495
#                                           gain ratio = 0.4166120232031104
#                                                 9
#                                                 Is age = 1.0?
#                                                 --> True:
#                                                 count of 0 = 1
#                                                 count of 1 = 0
#                                                 entropy = 0
#                                                 gain ratio = 0.5345806985518538
#                                                       reached node leaf
#                                                 9
#                                                 Is age = 1.0?
#                                                 --> False:
#                                                 count of 0 = 1
#                                                 count of 1 = 1
#                                                 entropy = 0.30102999566398114
#                                                 gain ratio = 0.5345806985518538
#                                                       reached node leaf
#                                     7
#                                     Is Has_Cabin = 1.0?
#                                     --> False:
#                                     count of 0 = 15
#                                     count of 1 = 12
#                                     entropy = 0.2983436219957756
#                                     gain ratio = 0.7937279129037291
#                                           8
#                                           Is FamilySize = 3.0?
#                                           --> True:
#                                           count of 0 = 8
#                                           count of 1 = 10
#                                           entropy = 0.2983436219957756
#                                           gain ratio = 0.7311099605457801
#                                                 9
#                                                 Is age = 2.0?
#                                                 --> True:
#                                                 count of 0 = 4
#                                                 count of 1 = 0
#                                                 entropy = 0
#                                                 gain ratio = 0.5830615750725547
#                                                       reached node leaf
#                                                 9
#                                                 Is age = 2.0?
#                                                 --> False:
#                                                 count of 0 = 5
#                                                 count of 1 = 9
#                                                 entropy = 0.2830542780615224
#                                                 gain ratio = 0.5830615750725547
#                                                       10
#                                                       Is age = 1.0?
#                                                       --> True:
#                                                       count of 0 = 5
#                                                       count of 1 = 3
#                                                       entropy = 0.28731326376205835
#                                                       gain ratio = 0.513926892375438
#                                                             reached node leaf
#                                                       10
#                                                       Is age = 1.0?
#                                                       --> False:
#                                                       count of 0 = 3
#                                                       count of 1 = 3
#                                                       entropy = 0.30102999566398114
#                                                       gain ratio = 0.513926892375438
#                                                             reached node leaf
#                                           8
#                                           Is FamilySize = 3.0?
#                                           --> False:
#                                           count of 0 = 6
#                                           count of 1 = 3
#                                           entropy = 0.27643459094367495
#                                           gain ratio = 0.7311099605457801
#                                                 9
#                                                 Is age = 2.0?
#                                                 --> True:
#                                                 count of 0 = 1
#                                                 count of 1 = 1
#                                                 entropy = 0.30102999566398114
#                                                 gain ratio = 0.43000107543396365
#                                                       reached node leaf
#                                                 9
#                                                 Is age = 2.0?
#                                                 --> False:
#                                                 count of 0 = 5
#                                                 count of 1 = 2
#                                                 entropy = 0.25982518101310587
#                                                 gain ratio = 0.43000107543396365
#                                                       10
#                                                       Is age = 1.0?
#                                                       --> True:
#                                                       count of 0 = 3
#                                                       count of 1 = 2
#                                                       entropy = 0.29228525323862886
#                                                       gain ratio = 0.40207823261175457
#                                                             reached node leaf
#                                                       10
#                                                       Is age = 1.0?
#                                                       --> False:
#                                                       count of 0 = 2
#                                                       count of 1 = 0
#                                                       entropy = 0
#                                                       gain ratio = 0.40207823261175457
#                                                             reached node leaf
#                         5
#                         Is fare = 1.0?
#                         --> False:
#                         count of 0 = 99
#                         count of 1 = 82
#                         entropy = 0.2991116126558021
#                         gain ratio = 3.0420431896080977
#                               6
#                               Is FamilySize = 7.0?
#                               --> True:
#                               count of 0 = 3
#                               count of 1 = 8
#                               entropy = 0.2544759887859944
#                               gain ratio = 2.3782357838800934
#                                     7
#                                     Is fare = 3.0?
#                                     --> True:
#                                     count of 0 = 6
#                                     count of 1 = 4
#                                     entropy = 0.29228525323862886
#                                     gain ratio = 0.4623898530505439
#                                           8
#                                           Is age = 2.0?
#                                           --> True:
#                                           count of 0 = 2
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.4456034007828225
#                                                 reached node leaf
#                                           8
#                                           Is age = 2.0?
#                                           --> False:
#                                           count of 0 = 4
#                                           count of 1 = 4
#                                           entropy = 0.30102999566398114
#                                           gain ratio = 0.4456034007828225
#                                                 reached node leaf
#                                     7
#                                     Is fare = 3.0?
#                                     --> False:
#                                     count of 0 = 0
#                                     count of 1 = 1
#                                     entropy = 0
#                                     gain ratio = 0.4623898530505439
#                                           reached node leaf
#                               6
#                               Is FamilySize = 7.0?
#                               --> False:
#                               count of 0 = 104
#                               count of 1 = 66
#                               entropy = 0.2900879388321769
#                               gain ratio = 2.3782357838800934
#                                     7
#                                     Is Has_Cabin = 1.0?
#                                     --> True:
#                                     count of 0 = 0
#                                     count of 1 = 3
#                                     entropy = 0
#                                     gain ratio = 2.288608601532368
#                                           8
#                                           Is age = 2.0?
#                                           --> True:
#                                           count of 0 = 0
#                                           count of 1 = 1
#                                           entropy = 0
#                                           gain ratio = 0.5346226168533992
#                                                 reached node leaf
#                                           8
#                                           Is age = 2.0?
#                                           --> False:
#                                           count of 0 = 2
#                                           count of 1 = 0
#                                           entropy = 0
#                                           gain ratio = 0.5346226168533992
#                                                 reached node leaf
#                                     7
#                                     Is Has_Cabin = 1.0?
#                                     --> False:
#                                     count of 0 = 100
#                                     count of 1 = 67
#                                     entropy = 0.29249484371671275
#                                     gain ratio = 2.288608601532368
#                                           8
#                                           Is fare = 3.0?
#                                           --> True:
#                                           count of 0 = 22
#                                           count of 1 = 9
#                                           entropy = 0.2616364821232255
#                                           gain ratio = 2.2676097762366583
#                                                 9
#                                                 Is age = 0.0?
#                                                 --> True:
#                                                 count of 0 = 5
#                                                 count of 1 = 3
#                                                 entropy = 0.28731326376205835
#                                                 gain ratio = 0.7932073639315526
#                                                       10
#                                                       Is FamilySize = 11.0?
#                                                       --> True:
#                                                       count of 0 = 0
#                                                       count of 1 = 1
#                                                       entropy = 0
#                                                       gain ratio = 0.4151568681974367
#                                                             reached node leaf
#                                                       10
#                                                       Is FamilySize = 11.0?
#                                                       --> False:
#                                                       count of 0 = 5
#                                                       count of 1 = 2
#                                                       entropy = 0.25982518101310587
#                                                       gain ratio = 0.4151568681974367
#                                                             11
#                                                             Is FamilySize = 5.0?
#                                                             --> True:
#                                                             count of 0 = 2
#                                                             count of 1 = 0
#                                                             entropy = 0
#                                                             gain ratio = 0.40207823261175457
#                                                                   reached node leaf
#                                                             11
#                                                             Is FamilySize = 5.0?
#                                                             --> False:
#                                                             count of 0 = 3
#                                                             count of 1 = 2
#                                                             entropy = 0.29228525323862886
#                                                             gain ratio = 0.40207823261175457
#                                                                   reached node leaf
#                                                 9
#                                                 Is age = 0.0?
#                                                 --> False:
#                                                 count of 0 = 11
#                                                 count of 1 = 12
#                                                 entropy = 0.30061937996055055
#                                                 gain ratio = 0.7932073639315526
#                                                       10
#                                                       Is FamilySize = 11.0?
#                                                       --> True:
#                                                       count of 0 = 6
#                                                       count of 1 = 3
#                                                       entropy = 0.27643459094367495
#                                                       gain ratio = 0.6666077911297065
# ...
#                                                             entropy = 0
#                                                             gain ratio = 0.40207823261175457
#                                                                   reached node leaf
#                                                       10
#                                                       Is fare = 2.0?
#                                                       --> False:
#                                                       count of 0 = 11
#                                                       count of 1 = 13
#                                                       entropy = 0.2995202785145496
#                                                       gain ratio = 0.7937996579818876
#                                                             11
#                                                             Is Has_Cabin = 1.0?
#                                                             --> True:
#                                                             count of 0 = 1
#                                                             count of 1 = 2
#                                                             entropy = 0.27643459094367495
#                                                             gain ratio = 0.6824452486761677
#                                                                   reached node leaf
#                                                             11
#                                                             Is Has_Cabin = 1.0?
#                                                             --> False:
#                                                             count of 0 = 11
#                                                             count of 1 = 10
#                                                             entropy = 0.3005374120319918
#                                                             gain ratio = 0.6824452486761677
#                                                                   12
#                                                                   Is embarked = 2.0?
#                                                                   --> True:
#                                                                   count of 0 = 0
#                                                                   count of 1 = 1
#                                                                   entropy = 0
#                                                                   gain ratio = 0.6330385793447761
#                                                                         reached node leaf
#                                                                   12
#                                                                   Is embarked = 2.0?
#                                                                   --> False:
#                                                                   count of 0 = 11
#                                                                   count of 1 = 9
#                                                                   entropy = 0.2988548895792612
#                                                                   gain ratio = 0.6330385793447761
#                                                                         reached node leaf
#                                           8
#                                           Is age = 2.0?
#                                           --> False:
#                                           count of 0 = 5
#                                           count of 1 = 1
#                                           entropy = 0.1956762467702946
#                                           gain ratio = 0.9290227807215173
#                                                 9
#                                                 Is fare = 0.0?
#                                                 --> True:
#                                                 count of 0 = 0
#                                                 count of 1 = 1
#                                                 entropy = 0
#                                                 gain ratio = 0.3939212620188948
#                                                       reached node leaf
#                                                 9
#                                                 Is fare = 0.0?
#                                                 --> False:
#                                                 count of 0 = 4
#                                                 count of 1 = 1
#                                                 entropy = 0.21732201127364886
#                                                 gain ratio = 0.3939212620188948
#                                                       10
#                                                       Is age = 4.0?
#                                                       --> True:
#                                                       count of 0 = 1
#                                                       count of 1 = 0
#                                                       entropy = 0
#                                                       gain ratio = 0.39373831991943087
#                                                             reached node leaf
#                                                       10
#                                                       Is age = 4.0?
#                                                       --> False:
#                                                       count of 0 = 3
#                                                       count of 1 = 1
#                                                       entropy = 0.24421905028821553
#                                                       gain ratio = 0.39373831991943087
#                                                             11
#                                                             Is fare = 2.0?
#                                                             --> True:
#                                                             count of 0 = 2
#                                                             count of 1 = 1
#                                                             entropy = 0.27643459094367495
#                                                             gain ratio = 0.4166120232031104
#                                                                   12
#                                                                   Is IsAlone = 1.0?
#                                                                   --> True:
#                                                                   count of 0 = 1
#                                                                   count of 1 = 0
#                                                                   entropy = 0
#                                                                   gain ratio = 0.5345806985518538
#                                                                         reached node leaf
#                                                                   12
#                                                                   Is IsAlone = 1.0?
#                                                                   --> False:
#                                                                   count of 0 = 1
#                                                                   count of 1 = 1
#                                                                   entropy = 0.30102999566398114
#                                                                   gain ratio = 0.5345806985518538
#                                                                         reached node leaf
#                                                             11
#                                                             Is fare = 2.0?
#                                                             --> False:
#                                                             count of 0 = 1
#                                                             count of 1 = 0
#                                                             entropy = 0
#                                                             gain ratio = 0.4166120232031104
#                                                                   reached node leaf
#                                     7
#                                     Is pclass = 2.0?
#                                     --> False:
#                                     count of 0 = 13
#                                     count of 1 = 14
#                                     entropy = 0.30073205751142396
#                                     gain ratio = 1.2875233673882147
#                                           8
#                                           Is fare = 2.0?
#                                           --> True:
#                                           count of 0 = 10
#                                           count of 1 = 11
#                                           entropy = 0.3005374120319918
#                                           gain ratio = 0.7308144035140441
#                                                 9
#                                                 Is Has_Cabin = 1.0?
#                                                 --> True:
#                                                 count of 0 = 5
#                                                 count of 1 = 6
#                                                 entropy = 0.2992329102507745
#                                                 gain ratio = 0.6331582903849469
#                                                       10
#                                                       Is embarked = 1.0?
#                                                       --> True:
#                                                       count of 0 = 2
#                                                       count of 1 = 3
#                                                       entropy = 0.29228525323862886
#                                                       gain ratio = 0.46254234189986737
#                                                             reached node leaf
#                                                       10
#                                                       Is embarked = 1.0?
#                                                       --> False:
#                                                       count of 0 = 4
#                                                       count of 1 = 2
#                                                       entropy = 0.27643459094367495
#                                                       gain ratio = 0.46254234189986737
#                                                             11
#                                                             Is age = 4.0?
#                                                             --> True:
#                                                             count of 0 = 0
#                                                             count of 1 = 1
#                                                             entropy = 0
#                                                             gain ratio = 0.3939212620188948
#                                                                   reached node leaf
#                                                             11
#                                                             Is age = 4.0?
#                                                             --> False:
#                                                             count of 0 = 4
#                                                             count of 1 = 1
#                                                             entropy = 0.21732201127364886
#                                                             gain ratio = 0.3939212620188948
#                                                                   reached node leaf
#                                                 9
#                                                 Is Has_Cabin = 1.0?
#                                                 --> False:
#                                                 count of 0 = 6
#                                                 count of 1 = 4
#                                                 entropy = 0.29228525323862886
#                                                 gain ratio = 0.6331582903849469
#                                                       10
#                                                       Is embarked = 1.0?
#                                                       --> True:
#                                                       count of 0 = 2
#                                                       count of 1 = 1
#                                                       entropy = 0.27643459094367495
#                                                       gain ratio = 0.44573432183404277
#                                                             11
#                                                             Is age = 2.0?
#                                                             --> True:
#                                                             count of 0 = 2
#                                                             count of 1 = 0
#                                                             entropy = 0
#                                                             gain ratio = 0.5346226168533992
#                                                                   reached node leaf
#                                                             11
#                                                             Is age = 2.0?
#                                                             --> False:
#                                                             count of 0 = 0
#                                                             count of 1 = 1
#                                                             entropy = 0
#                                                             gain ratio = 0.5346226168533992
#                                                                   reached node leaf
#                                                       10
#                                                       Is embarked = 1.0?
#                                                       --> False:
#                                                       count of 0 = 4
#                                                       count of 1 = 3
#                                                       entropy = 0.296583221518423
#                                                       gain ratio = 0.44573432183404277
#                                                             reached node leaf
#                                           8
#                                           Is fare = 2.0?
#                                           --> False:
#                                           count of 0 = 4
#                                           count of 1 = 2
#                                           entropy = 0.27643459094367495
#                                           gain ratio = 0.7308144035140441
#                                                 9
#                                                 Is Has_Cabin = 1.0?
#                                                 --> True:
#                                                 count of 0 = 3
#                                                 count of 1 = 1
#                                                 entropy = 0.24421905028821553
#                                                 gain ratio = 0.3936395446599453
#                                                       reached node leaf
#                                                 9
#                                                 Is Has_Cabin = 1.0?
#                                                 --> False:
#                                                 count of 0 = 1
#                                                 count of 1 = 1
#                                                 entropy = 0.30102999566398114
#                                                 gain ratio = 0.3936395446599453
#                                                       reached node leaf

# %%
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %% [markdown]
# # Evaluation

# %%
for rowx,rowy in zip(x_test,y_test):
    print ("Actual: %s. Predicted: %s" %
           (rowy, print_leaf(classify(rowx, my_tree))))
# Out:
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '35%', 1: '64%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '71%', 1: '28%'}
# Actual: 1.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '40%', 1: '60%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '20%', 1: '80%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 1.0. Predicted: {0: '62%', 1: '37%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 1.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '42%', 1: '57%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 1.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 1.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 1.0. Predicted: {0: '25%', 1: '75%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '44%'}
# Actual: 1.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '62%', 1: '37%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 1.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '44%'}
# Actual: 0.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '71%', 1: '28%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '44%'}
# Actual: 1.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '25%', 1: '75%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '35%', 1: '64%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '71%', 1: '28%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 1.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '71%', 1: '28%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 1.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 1.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 1.0. Predicted: {0: '42%', 1: '57%'}
# Actual: 0.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 1.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 1.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 1.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 1.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '80%', 1: '20%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '62%', 1: '37%'}
# Actual: 0.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 1.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '57%', 1: '42%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '44%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '35%', 1: '64%'}
# Actual: 0.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '44%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '83%', 1: '16%'}
# Actual: 0.0. Predicted: {0: '25%', 1: '75%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '62%', 1: '37%'}
# Actual: 0.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 1.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 1.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '58%', 1: '41%'}
# Actual: 1.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '47%', 1: '52%'}
# Actual: 1.0. Predicted: {0: '71%', 1: '28%'}
# Actual: 0.0. Predicted: {0: '66%', 1: '33%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '33%', 1: '66%'}
# Actual: 0.0. Predicted: {0: '75%', 1: '25%'}
# Actual: 1.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 0.0. Predicted: {0: '48%', 1: '52%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '62%', 1: '37%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '50%', 1: '50%'}
# Actual: 1.0. Predicted: {0: '71%', 1: '28%'}
# Actual: 0.0. Predicted: {0: '0%', 1: '100%'}
# Actual: 0.0. Predicted: {0: '35%', 1: '64%'}
# Actual: 0.0. Predicted: {0: '53%', 1: '46%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '20%', 1: '80%'}
# Actual: 1.0. Predicted: {0: '55%', 1: '44%'}
# Actual: 1.0. Predicted: {0: '60%', 1: '40%'}
# Actual: 0.0. Predicted: {0: '44%', 1: '55%'}
# Actual: 0.0. Predicted: {0: '55%', 1: '45%'}
# Actual: 0.0. Predicted: {0: '54%', 1: '45%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
# Actual: 1.0. Predicted: {0: '100%', 1: '0%'}
# Actual: 0.0. Predicted: {0: '52%', 1: '47%'}
